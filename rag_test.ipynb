# %%
first_question_article = [
     {'article_id': '00000194-25d6-dcc4-a1d7-3df6703c0000',
      'question': 'אני רוצה לקרוא ביקורת על הסרט החדש של לוקה גואדנינו, זה שמבוסס על ספר של בורוז על הומו שחי במקסיקו בשנות ה-50 ומחפש גברים צעירים.'},
      {'article_id': '00000194-2618-dd68-a3be-e6fc06680000',
       'question': 'אני מחפש ביקורת על הסרט החדש עם ניקול קידמן, זה שהיא משחקת בו מנכ"לית חברת רובוטיקה שיש לה רומן עם מתמחה צעיר. הסרט הוקרן בפסטיבל ונציה, איך הוא?.'
       },
       {'article_id': '00000194-2681-ddb6-afdd-77e781220000',
        'question': 'אני מחפש ביקורת על הסרט החדש של עמוס גיתאי, זה שעוסק בשאלה למה יש מלחמות ומשתמש במכתבים של איינשטיין ופרויד.'
        },
        {'article_id': '00000194-2b97-‎d9c2-a79e-2bd7330c0000',
            'question': 'אפשר בבקשה ביקורת על הסרט החדש "נוספרטו" של רוברט אגרס? אני רוצה לדעת אם הוא נאמן למקורות של סרטי הערפדים הקלאסיים ואיך השחקנים הראשיים, במיוחד לילי-רוז דפ, משחקים?'
        },
        {'article_id': '00000194-319b-d555-abbc-b1dfdf250000',
            'question': '"אני מחפש ביקורת על סרט חדש שמוקרן בפסטיבל חיפה, על אישה אלכוהוליסטית בשם רונה שחוזרת לאי הולדתה בסקוטלנד כדי להתמודד עם ההתמכרות שלה. מישהי כתבה על זה ביקורת?'
        },
        {
            'article_id': '00000194-31db-ddaf-adb7-7bfbaf200000',
            'question': 'אני מחפש סרט איראני חדש שמתרחש בטהרן ועוסק במשפחה שאבא שלה שופט ורואים בו גם קטעים מההפגנות שם. ראיתי שהקרינו אותו בפסטיבל חיפה'
        },
        {'article_id': '00000194-34df-d39d-a196-b7ff86ce0000',
            'question': '"אני מחפש סדרת אנימציה חדשה בנטפליקס, משהו בסגנון באפי קוטלת הערפדים אבל עם מיתולוגיה סינית. שמעתי שיש סדרה על נערה סינית-אמריקאית שנלחמת בשדים, מישהו מכיר?',
        },
        {
            'article_id':"00000194-356b-de88-a3dc-75ef26460000",
            'question':"אוקיי, שמעתי על סרט חדש של שבי גביזון עם ריצ'רד גיר על אבא שמגלה שהיה לו בן שנהרג. איך קוראים לסרט ומה הוא מספר עליו?"
        },
        {
        'article_id':'00000194-4be5-dff1-a7bc-dbf57a210000',
        'question':'אני מחפש סרט על שני בני דודים יהודים אמריקאים שנוסעים לפולין בעקבות השואה. אחד מהם משחק בסדרה "יורשים". מישהו כתב וביים את הסרט והוא גם שחקן בסרט "הרשת החברתית".',
        },
        {
        'article_id':'00000194-6e60-d9d3-a597-eeecd15d0000',
        'question':'"אני מחפש מידע על הסרט החדש של ארז תדמור, זה שמתרחש בשנות ה-50 ליד הכנרת ועוסק בפרטיזנים לשעבר שעובדים במפעל סודה. איך קוראים לסרט ומה העלילה שלו?',
        },
          {
    "article_id": "00000194-d160-df91-ab95-ff6aad5c0000",
    "question": "היי, שמעתי על סדרה חדשה ביס על ההתקפה על שגרירות ישראל במצרים ב-2011. מישהו כתב על זה ביקורת? אני מחפש את הביקורת על הפרק הראשון של הסדרה הזאת, זה נקרא \"תחריר\" נראה לי."
  },
  {
    "article_id": "00000194-d4d0-d558-a1d4-fed913de0000",
    "question": "אני מחפש סדרה בנטפליקס על קומיקאי פלסטיני שגר בארצות הברית ומסתבך עם עצי זית גנובים ומנסה לקבל אזרחות. שמעתי שהעונה השנייה יותר פוליטית ויש בה ביקורת על ישראל, אבל פחות טובה מהעונה הראשונה. מישהו מכיר?"
  },
  {
    "article_id": "00000194-d5b3-de15-a5f4-ddfbd5bf0000",
    "question": "היי, שמעתי על סדרה חדשה על תעשיית הנפט בטקסס, משהו על טורבינות רוח שמשמשות להפקת נפט ועל השפעות סביבתיות. מישהו כתב על זה ביקורת בעיתון הארץ לאחרונה?"
  },
  {
    "article_id": "00000194-d6b7-ddbc-a1dd-d6b745840000",
    "question": "אני מחפש ביקורת על הסרט החדש על בוב דילן, זה שמספר על התקופה שהוא עבר ממוזיקת פולק לרוקנרול ועל המעבר מגיטרה אקוסטית לחשמלית."
  },
  {
    "article_id": "00000194-d72f-ddbc-a1dd-d7afd7900000",
    "question": "אני מחפש ביקורת על סרט ישראלי חדש על אחות טיפת חלב בשכונת חליסה בחיפה, שמנסה לעזור למטופלות שלה וגם לעצמה להרות, בכיכובה של נועה קולר."
  },
  {
    "article_id": "00000194-daa2-df08-a3bc-debf77de0000",
    "question": "אני מחפש ביקורת על סרט ישראלי חדש, משהו על אישה שמציגה את התינוקת של חברה שלה כבת שלה, ויש שם גם נהג אוטובוס שמספר על זה. הבנתי שהשחקנית הראשית שם ממש טובה."
  },
  {
    "article_id": "00000194-e97a-d168-a3bf-e9fadf380000",
    "question": "אני מחפש סדרה בנטפליקס על האישה האוסטרלית שהתחזתה לחולת סרטן שהחלימה בעזרת תזונה, מה השם שלה?"
  },
  {
    "article_id": "00000194-f8d1-dd66-a3b4-ffff92f60000",
    "question": "אוקיי, איך קוראים לסדרה הזאת בנטפליקס, זאת על הבלשית שמגיעה לעיירת סקי בשוודיה אחרי שנערה נעלמת ומוצאים גופה ליד פסי רכבת?"
  },
  {
    "article_id": "00000194-fa9b-d00a-adfc-fadfeb9d0000",
    "question": "אני מחפש כתבה על מערכון ב\"סאטרדיי נייט לייב\" עם כריסטופר ווקן ווויל פארל, זה שמנגנים בפעמון פרה. מה היה הסיפור מאחורי המערכון הזה?"
  },
  {
    "article_id": "00000194-fe33-d1d7-a9d5-fe77dd600000",
    "question": "אפשר בבקשה מידע על סרט ישראלי חדש שמדבר על שחקן שחוזר ממילואים ומסתבך בגלל הצגה שהוא מעלה במתנ\"ס? משהו עם פוסט טראומה וויכוח על חופש הביטוי."
  },
  {
    "article_id": "00000194-fe81-d1d7-a9d5-fec5175c0000",
    "question": "אפשר בבקשה ביקורת על הסרט החדש של קפטן אמריקה, זה שמשתתפת בו שירה האס והנשיא הוא הריסון פורד? איך הוא ביחס לסרטים אחרים של מארוול?"
  },
  {
    "article_id": "00000194-feb9-df1c-ad94-ffbf09620000",
    "question": "אני מחפש ביקורת על סרט צרפתי חדש על אהבה בין צעירים שמעורבים בפשע, עם אדל אקסרקופולוס ופרנסואה סיביל. הסרט הזה היה מועמד לכמה פרסי סזאר ויצא בפסטיבל קאן."
  },
  {
    "article_id": "00000195-030d-d598-add5-3b1d8d8f0000",
    "question": "אני מחפש סדרה חדשה על הפיגוע בשגרירות ישראל בארגנטינה ב-92, איך קוראים לה ומה הביקורות עליה?"
  },
  {
    "article_id": "00000195-0d2d-d00a-adfd-6dff60910000",
    "question": "אפשר בבקשה ביקורת על הסדרה הפינית הזאת בהוט, על הפלישה לעיירה בחצי אי כזה, משהו על חיילים שנלקחים בשבי ונשיאה צעירה?"
  },
  {
    "article_id": "00000195-0fdd-d0af-a197-cfdda7e00000",
    "question": "חיפשתי ביקורת על הסרט החדש של ברידג'ט ג'ונס, זה שהיא חוזרת לשוק הרומנטי אחרי שהיא כבר בת 50 ואמא לשניים, ובעלה מת. איך הסרט?"
  },
  {
    "article_id": "00000195-177c-d57f-a9df-77fd0a8e0000",
    "question": "אוקיי, שמעתי שהעונה החדשה של \"הלוטוס הלבן\" יצאה. מה כתבו עליה? כדאי לראות את העונה הזאת בתאילנד, או שהיא פחות טובה מהקודמות?"
  },
  {
    "article_id": "00000195-1dbd-d100-a5d5-bfbf19f10000",
    "question": "איפה אפשר למצוא מידע על סדרת טלוויזיה שמבוססת על סיפור אמיתי של שחקן פוטבול מפורסם שהורשע ברצח והתאבד בכלא?"
  },
  {
    "article_id": "00000195-2238-df71-a5fd-eab99cff0000",
    "question": "אני מחפש סרט על אדריכל ניצול שואה שהיגר לאמריקה אחרי המלחמה ועבד בסגנון הברוטליסטי. הוא בטח הופיע בפסטיבל ונציה ורץ לאוסקר, נכון?"
  },
  {
    "article_id": "00000195-2272-d293-a1d5-e67745670000",
    "question": "אפשר בבקשה מידע על הסרט הברזילאי הזה, על המשפחה שחיה בדיקטטורה בשנות ה-70, שהאבא שלהם נלקח? הבנתי שהסרט מבוסס על סיפור אמיתי."
  },
  {
    "article_id": "00000195-3138-d670-ad97-7dff432f0000",
    "question": "אוקיי, שמעתי שרוברט דה נירו משחק נשיא אמריקאי לשעבר בסדרה חדשה בנטפליקס, משהו על מתקפת סייבר וקונספירציה. מה הביקורות אומרות עליה?"
  },
  {
    "article_id": "00000195-345b-d641-abfd-b77bc8b10000",
    "question": "אפשר בבקשה מידע על סרט ישראלי חדש שמדבר על משפחה חרדית מזרחית בבני ברק, והבן שלהם עילוי שרוצה להתקבל לישיבה ליטאית יוקרתית? הבנתי שהסרט עוסק בגזענות וקושי השתייכות."
  },
    {
    "article_id": "00000194-87a3-dee1-aff7-e7ffd07d0000",
    "question": "היי, רציתי למצוא כתבה על תוכנית ריאליטי חדשה בערוץ 13, משהו על זוגות שצריכים להחליט כל כמה ימים אם להישאר ביחד, והמנחה היא מאיה ורטהיימר. ראיתי שהעונה הזאת יותר צעירה מהעונות הקודמות."
  },
  {
    "article_id": "00000194-8ca3-d963-a39c-fef3b8010000",
    "question": "אוקיי, שמעתי על סדרה חדשה באפל טיוי פלוס על מתמטיקאי גאון שנקלע לקונספירציה. איך קוראים לה, ומה הביקורת עליה?"
  },
  {
    "article_id": "00000194-8cfd-d963-a39c-fefdda8e0000",
    "question": "אפשר בבקשה מידע על סדרה חדשה בהוט, על שני בני דודים שחקני כדורגל שאחד מהם מסתבך עם ארגון פשיעה?"
  },
  {
    "article_id": "00000194-91e0-d5db-a7f5-b1ecf8a40000",
    "question": "אני מחפש ביקורת על סרט אנימציה חדש על השואה, משהו על זוג שמוצא תינוקת יהודיה נטושה ביער ליד פסי רכבת. זה מתחיל כמו אגדה אבל אז הופך להיות יותר ויותר קשה."
  },
  {
    "article_id": "00000194-9316-dc28-abb5-b75fabfb0000",
    "question": "אני מחפש ביקורת על סרט אימה חדש שצולם מנקודת מבט של רוח רפאים בבית רדוף, משהו על איך חוויית הצפייה משפיעה על הפחד ואיך זה עובד כדרמה משפחתית."
  },
  {
    "article_id": "00000194-a115-d1bc-a7de-f57dfab60000",
    "question": "היי, מחפש מידע על סדרת מתח בנטפליקס, משהו על סוכן FBI זוטר שנקלע לקונספירציה בבית הלבן וצריך להגן על מומחית סייבר, ראיתי שהייתה לה עונה שנייה שמתרחשת גם בתאילנד, יש ביקורת על העונה השנייה?"
  },
  {
    "article_id": "00000194-a18a-d1bc-a7de-f5ff17920000",
    "question": "אני מחפש כתבה על אייס אוף בייס, הלהקה השוודית הזאת, הבנתי שעשו עליהם איזה סרט דוקומנטרי חדש שמספר גם על זה שאחד מהם היה קשור לכנופיה ניאו-נאצית, ואיך הם התמודדו עם זה בתחילת הקריירה. מעניין אותי לקרוא על זה יותר."
  },
  {
    "article_id": "00000194-b0e5-da2c-a5dd-beed8fd40000",
    "question": "היי, שמעתי שיצאה סדרה אמריקאית חדשה על סוכני CIA בלונדון, רימייק לסדרה צרפתית מצליחה. מישהו יודע איך היא?"
  },
  {
    "article_id": "00000194-b19c-d8c8-a795-b9dfffeb0000",
    "question": "היי, אני מחפש ביקורת טלוויזיה על סדרת פריקוול לסדרה \"שטיסל\", משהו על משפחה חרדית שעוברת לאנטוורפן ועל אבא נוכל שמרמה אלמנות."
  },
  {
    "article_id": "00000194-b61b-dee1-a5dc-f6fb45b20000",
    "question": "אני מחפש סרט חדש על בחירת אפיפיור בוותיקן, משהו על מאבקי כוח וקרדינלים שמנסים להשפיע על הבחירה, עם עשן לבן שיוצא מהארובה. יש המלצות?"
  },
  {
    "article_id": "00000194-b639-d5a7-ab9d-f7b934750000",
    "question": "אני מחפש מידע על סרט חדש שיצא על הטבח של הספורטאים באולימפיאדת מינכן, אבל הפעם מנקודת המבט של צוות טלוויזיה אמריקאי ששידר את האירוע בזמן אמת. מישהו יודע איך קוראים לו ואיפה אפשר לראות אותו?"
  },
  {
    "article_id": "00000194-b6ad-d69b-a3b7-b7ef897f0000",
    "question": "אני מחפש מידע על סרט אנימציה פוסט אפוקליפטי על חתול וחבורת חיות ששטים בסירה. הסרט בלי דיאלוגים ונוצר בתקציב נמוך, הוא מועמד לאוסקר?"
  },
    {
    "article_id": "00000194-46df-dff1-a7bc-dfff85f10000",
    "question": "אני מחפש סרט על גיאורגית שגרה ברוסיה וקונה דירה מקשיש רוסי, ואז יש בעיות עם המשטרה שמגרשת מהגרים. שמעתי שהיו בעיות עם הצילומים ברוסיה."
  },
  {
    "article_id": "00000194-4a1e-db19-abdd-6a9fb15c0000",
    "question": "אני מחפש סרט על צעירה מצרפת שמנסה להיות משפיענית רשת, והיא מצלמת את עצמה בחדר שלה ורוקדת מול הטלפון. היא גם גונבת מחנויות. איך קוראים לסרט הזה?"
  },
  {
    "article_id": "00000194-4be7-dff1-a7bc-dbf7c5430000",
    "question": "אני מחפש סרט איטלקי חדש על מורה ותלמידה שלו שמתאהבים, ואז הם מגלים סודות אחד על השני ויש שם מתח ורומנטיקה. מישהו מכיר?"
  },
  {
    "article_id": "00000194-643a-df8d-abbd-fdfee6bd0000",
    "question": "אני מחפש ביקורת על הסרט החדש על רובי וויליאמס, זה שהדמות שלו שם היא בכלל קוף דיגיטלי, שמעתי שהוא לא משהו."
  },
  {
    "article_id": "00000194-695e-de89-a5df-697f6e7d0000",
    "question": "אילו סדרות חוזרות למסך אחרי השביתה בהוליווד, ומה עוד חדש הולך להיות בטלוויזיה השנה?"
  },
  {
    "article_id": "00000194-6a20-d876-affe-7e2bbee40000",
    "question": "אני מחפש מאמר שמתייחס לביקורת על העונה השנייה של \"משחק הדיונון\" בנטפליקס, במיוחד על החלוקה שלה לשני חלקים ואיך זה פגע בחוויית הצפייה."
  },
  {
    "article_id": "00000194-6eaa-d545-a39e-eeeae7c10000",
    "question": "אני מחפש סרט על מהגר לא חוקי מגינאה שמנסה לקבל אישור שהייה בצרפת, הוא עובד כשליח על אופניים בפריז ויש לו כתם דם על החולצה. מישהו יודע על מה אני מדבר?"
  },
  {
    "article_id": "00000194-7369-dce1-a396-f76929bd0000",
    "question": "אוקיי, שמעתי שיש סרט חדש עם קיליאן מרפי על איש פחם באירלנד בשנות ה-80, משהו קתולי כזה על מוסר ואחריות חברתית. מישהו ראה ויכול להמליץ?"
  },
  {
    "article_id": "00000194-7d04-dd7c-ab9e-fd8fe21c0000",
    "question": "אפשר בבקשה מידע על הסדרה הזאת שאנשים עוברים בה ניתוח שמפריד בין החיים האישיים לעבודה? שמעתי שיש לה עונה שנייה שמזכירה קצת את \"טווין פיקס\"."
  },
  {
    "article_id": "00000194-7e0c-de1b-a9bd-7f4f295e0000",
    "question": "אני מחפש מאמר שמדבר על ההשפעה של הסדרה \"טווין פיקס\" על הטלוויזיה ועל סדרות כמו \"אבודים\" ו\"הנותרים\"."
  },
  {
    "article_id": "00000194-8325-d640-a99e-ab6d1e970000",
    "question": "אני מחפש כתבה על סרט דוקומנטרי חדש על זאב רווח, שמדבר על הקריירה שלו ועל המחלוקות סביב הדמות שלו, במיוחד בקשר לסרטים שהוא ביים ושחקניות טענו שהיו שם סצנות בעייתיות."
  }


]

# %%
for i in first_question_article:
# Out:
#   Cell In[24], line 2
#
#     ^
# SyntaxError: incomplete input
