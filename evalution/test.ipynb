# %%
first_question_article = [
    #  {'article_id': '00000194-25d6-dcc4-a1d7-3df6703c0000',
    #   'question': 'אני רוצה לקרוא ביקורת על הסרט החדש של לוקה גואדנינו, זה שמבוסס על ספר של בורוז על הומו שחי במקסיקו בשנות ה-50 ומחפש גברים צעירים.'},
    #   {'article_id': '00000194-2618-dd68-a3be-e6fc06680000',
    #    'question': 'אני מחפש ביקורת על הסרט החדש עם ניקול קידמן, זה שהיא משחקת בו מנכ"לית חברת רובוטיקה שיש לה רומן עם מתמחה צעיר. הסרט הוקרן בפסטיבל ונציה, איך הוא?.'
    #    },
    #    {'article_id': '00000194-2681-ddb6-afdd-77e781220000',
    #     'question': 'אני מחפש ביקורת על הסרט החדש של עמוס גיתאי, זה שעוסק בשאלה למה יש מלחמות ומשתמש במכתבים של איינשטיין ופרויד.'
    #     },
    #     {'article_id': '00000194-2b97-d9c2-a79e-2bd7330c0000',
    #         'question': 'אפשר בבקשה ביקורת על הסרט החדש "נוספרטו" של רוברט אגרס? אני רוצה לדעת אם הוא נאמן למקורות של סרטי הערפדים הקלאסיים ואיך השחקנים הראשיים, במיוחד לילי-רוז דפ, משחקים?'
    #     },
    #     {'article_id': '00000194-319b-d555-abbc-b1dfdf250000',
    #         'question': '"אני מחפש ביקורת על סרט חדש שמוקרן בפסטיבל חיפה, על אישה אלכוהוליסטית בשם רונה שחוזרת לאי הולדתה בסקוטלנד כדי להתמודד עם ההתמכרות שלה. מישהי כתבה על זה ביקורת?'
    #     },
    #     {
    #         'article_id': '00000194-31db-ddaf-adb7-7bfbaf200000',
    #         'question': 'אני מחפש סרט איראני חדש שמתרחש בטהרן ועוסק במשפחה שאבא שלה שופט ורואים בו גם קטעים מההפגנות שם. ראיתי שהקרינו אותו בפסטיבל חיפה'
    #     },
    #     {'article_id': '00000194-34df-d39d-a196-b7ff86ce0000',
    #         'question': '"אני מחפש סדרת אנימציה חדשה בנטפליקס, משהו בסגנון באפי קוטלת הערפדים אבל עם מיתולוגיה סינית. שמעתי שיש סדרה על נערה סינית-אמריקאית שנלחמת בשדים, מישהו מכיר?',
    #     },
    #     {
    #         'article_id':"00000194-356b-de88-a3dc-75ef26460000",
    #         'question':"אוקיי, שמעתי על סרט חדש של שבי גביזון עם ריצ'רד גיר על אבא שמגלה שהיה לו בן שנהרג. איך קוראים לסרט ומה הוא מספר עליו?"
    #     },
    #     {
    #     'article_id':'00000194-4be5-dff1-a7bc-dbf57a210000',
    #     'question':'אני מחפש סרט על שני בני דודים יהודים אמריקאים שנוסעים לפולין בעקבות השואה. אחד מהם משחק בסדרה "יורשים". מישהו כתב וביים את הסרט והוא גם שחקן בסרט "הרשת החברתית".',
    #     },
    #     {
    #     'article_id':'00000194-6339-dabc-afff-6b7fb6e90000',
    #     'question':'אוקיי, שמעתי שיש סדרה חדשה בנטפליקס, מין מערבון כזה אבל ממש קשוח, עם הרבה אלימות וטבח. זה על איזה אישה שמנסה לשרוד עם הבן שלה בתקופה של מלחמת יוטה והטבח בהר מדוז. מישהו יודע על מה אני מדבר?',
    #     },
    #     {
    #     'article_id':'00000194-6e60-d9d3-a597-eeecd15d0000',
    #     'question':'"אני מחפש מידע על הסרט החדש של ארז תדמור, זה שמתרחש בשנות ה-50 ליד הכנרת ועוסק בפרטיזנים לשעבר שעובדים במפעל סודה. איך קוראים לסרט ומה העלילה שלו?',
    #     },
]

first_question_genre = [
    "אחי, תמליץ לי על איזה סרט אקשן טוב בנטפליקס? משהו חדש יחסית.",
    "מחפשת סדרה קלילה ומצחיקה, קומדיה כזאת, לא משנה לי באיזה שירות סטרימינג.",
    "מה כדאי לראות עכשיו ביס פלוס? בא לי איזה משהו מתח טוב.",
    "יש לך המלצה לסרט דרמה איכותי? עדיף משהו שזמין בהוט.",
    "אני והחבר'ה רוצים לראות סרט אימה הערב. יש משהו ממש מפחיד שאתה מכיר?",
    "תגיד, יש איזה סדרת מדע בדיוני שווה בפרטנר TV או בסלקום TV?",
    "בא לי לראות סרט ישראלי טוב, יש משהו מומלץ לאחרונה?",
    "מחפש סדרה לבינג', משהו שאפשר לטחון בסופ\"ש. ז'אנר פחות קריטי, העיקר שתהיה ממכרת.",
    "יש סרטי דוקו מעניינים בדיסני פלוס או באפל טי וי?",
    "סתם תן המלצה לסרט טוב שראית לאחרונה, לא משנה לי הז'אנר או הפלטפורמה."

]

genre_questions_as_dicts = [
    {'article_id': '', 'question': q} for q in first_question_genre
]

# איחוד שתי הרשימות לרשימה אחת
combined_questions = first_question_article + genre_questions_as_dicts

second_question = 'איזה יצירה המבקר העדיף יותר?'
thierd_question = 'אם הייתי אומר לך שאני במיוחד רגיש לסיומים מאכזבים/לא סגורים, איזו יצרה עדיפה מבין אלו שהמלצת?'

# %%
# Follow-up questions appropriate after a *general* first question that returned two recommendations
general_follow_up_questions = [
    "תסביר בפירוט איך הגעת להמלצה הזאת, ואיזה קטעים ספציפיים מתוך הכתבות תמכו בבחירה.",
    "יש לי רתיעה מאלימות גרפית. האם הסרט שהמלצת עליו כולל סצנות כאלה? תצטט מהמקורות שלך.",
    "האם יש סרט מתח ישראלי שעונה על אותם קריטריונים? נמק עם מקורות.",
    "אני מעדיף סרטים קצרים (עד 100 דקות). תעדכן את ההמלצה בהתאם.",
    "הסרט שהצעת כבר ראיתי. הבא המלצה אחרת, אבל שמור על הסיבות לבחירה שהצגת.",
    "תן לי טריילר רשמי (YouTube) וקישור לביקורת מהשנה האחרונה.",
    "אפשר להמליץ לי על סדרת טלוויזיה באותו סגנון, לפי אותם מקורות?",
    "מי קהל היעד העיקרי של הסרט לפי הנתונים במקורות?",
    "שכנע צופה שלא אוהב סרטי מתח מדוע כדאי לו בכל זאת לראות את הסרט שהצעת.",
    "האם קיימות אזהרות תוכן (trigger warnings) רלוונטיות? הבא ציטוט מפורט."
]

# Follow-up questions appropriate after a *specific* first question that returned a single recommendation
specific_follow_up_questions = [
    "תוכל להשוות בין הסרט שהצעת לבין ‘Seven’ מבחינת עלילה וטון?",
    "האם בסרט שהמלצת יש ייצוג נשי משמעותי? צטט ביקורות שמדברות על כך.",
    "מהן שלוש נקודות הביקורת העיקריות שהוזכרו נגד הסרט במקורות שהבאת?",
    "אשמח לתקציר נטול ספוילרים של 100 מילים בדיוק.",
    "מי מהשחקנים הראשיים היה מועמד/זכה בפרסים, ועל אילו תפקידים אחרים הם ידועים?",
    "האם הסרט מבוסס על ספר? אם כן, מה ההבדלים העיקריים לפי הכתבות?",
    "מהו המוטיב המרכזי (theme) ששב ועולה בביקורות, ואיך הוא בא לידי ביטוי בסצנה ספציפית?",
    "האם יש פסקול בולט במיוחד? נסח ביקורת קצרה על המוזיקה וציין ציטוט ממקור.",
    "מהן הנקודות שהמבקרים הכי שיבחו בצילום (cinematography)? הבא שתי דוגמאות וציטוטים.",
    "מבחינת Diversity & Inclusion—האם הסרט קיבל ביקורת חיובית או שלילית? הבא נתונים.",
    "האם יש Easter Eggs נסתרים שהמבקרים הזכירו? פרט שניים עם הפניות."
]

second_question_article = specific_follow_up_questions + general_follow_up_questions

# %%
from src.llm_api_client import LLMClient
from config.load_config import load_config

from test_antrpoic.antropic import ChatBot
from src.redis_chat_history import RedisChatHistory
import streamlit as st


prompts = load_config("config/prompts.yaml")
sys_instruct = prompts.get("system_instructions")
config = load_config("config/config.yaml")
llm_cfg = config.get("llm", {})

redis_store = RedisChatHistory()
llm_client = LLMClient(
    model_name=llm_cfg.get("llm_model_name"),
    api_key=llm_cfg.get("GOOGLE_API_KEY"),
    sys_instruct=sys_instruct,
    config=config,
    redis_store=redis_store,
)
# Initialize the LLM client antropic
antrp = ChatBot(config)

result = []

import numpy as np
counter = np.random.randint(0, 9999999999)


for q in combined_questions:
    st.session_state.messages = []
    counter += 1


    print('\n')
    print("="*20)
    article_id = q.get('article_id')
    question = q.get('question')
    print(f"Article ID: {article_id}")
    print(f"Question: {question}")
    
    full_response = ""
    ans = llm_client.streaming_message(question,f'{counter}')
    async for chunk in ans:
        print(chunk, end='', flush=True)
        if chunk:
            full_response += chunk


    second_question = second_question_article.pop(0)

    print('\n')
    print("="*20)
    print(f"Second Question: {second_question}")
    second_answer = ""
    ans = llm_client.streaming_message(second_question,f'{counter}')
    async for chunk in ans:
        if chunk:
            second_answer += chunk
        print(chunk, end='', flush=True)

    # thierd_answer = ""
    # ans = llm_client.streaming_message(thierd_question,f'{counter}')
    # async for chunk in ans:
    #     if chunk:
    #         thierd_answer += chunk
    #     print(chunk, end='', flush=True)



    # print('antrpoic answer')
    # antropic_answer, state = antrp.process_user_input(question,st.session_state)
    # print(antropic_answer)
    # second_answer_antrpoic, state = antrp.process_user_input(second_question,state)
    # print(second_answer_antrpoic)
    # thierd_answer_antrpoic, state = antrp.process_user_input(thierd_question,state)
    # print(thierd_answer_antrpoic)

    result.append({
        'article_id': article_id,
        'question': question,
        'answer_gemini': full_response,
        'second_question': second_question,
        'second_answer_gemini': second_answer,
        # 'answer_antrp': antropic_answer,
        # 'second_answer_gemini': second_answer,
        # 'second_answer_antrp': second_answer_antrpoic,
        # 'thierd_answer_gemini': thierd_answer,
        # 'thierd_answer_antrp': thierd_answer_antrpoic
    })
# Out:
# {"asctime": "2025-05-07 12:35:28,315", "name": "UNKNOWN_APP_NAME_logger", "levelname": "INFO", "message": "Successfully connected to Redis."}
# /Users/roeishlezinger/Desktop/movie-recommendation-chatbot/src/tools/search/utillity/qdrant.py:9: UserWarning: Qdrant client version 1.13.3 is incompatible with server version 1.8.4. Major versions should match and minor version difference must not exceed 1. Set check_version=False to skip version check.
#   self.client_qdrant = QdrantClient(config)
# /Users/roeishlezinger/Desktop/movie-recommendation-chatbot/src/tools/search/utillity/qdrant.py:9: UserWarning: Qdrant client version 1.13.3 is incompatible with server version 1.8.4. Major versions should match and minor version difference must not exceed 1. Set check_version=False to skip version check.
#   self.client_qdrant = QdrantClient(config)
# 2025-05-07 12:35:31.261 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-07 12:35:31.262 WARNING streamlit.runtime.state.session_state_proxy: Session state does not function when running a script without `streamlit run`
# 2025-05-07 12:35:31.262 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# {"asctime": "2025-05-07 12:35:31,335", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "No history found for user 1945513698 in Redis."}
# ====================
# Article ID:
# Question: אחי, תמליץ לי על איזה סרט אקשן טוב בנטפליקס? משהו חדש יחסית.
# Warning: there are non-text parts in the response: ['function_call'],returning concatenated text result from text parts,check out the non text parts for full response from model.
# {"asctime": "2025-05-07 12:35:33,994", "name": "UNKNOWN_APP_NAME_logger", "levelname": "INFO", "message": "query=סרט אקשן חדש יחסית בנטפליקס, streaming=['Netflix'], genres=['אקשן'], media_type=movie"}
# {"asctime": "2025-05-07 12:35:35,415", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Raw search_results for cost tracking: [{\"actors\": [\"אנטוני מקי\", \"דמסון אידריס\", \"מייקל קלי\", \"פילו אסבאק\", \"אמילי ביצ'ם\"], \"article_id\": \"0000017f-dbd7-d856-a37f-ffd7d9760000\", \"article_name\": \"\\\"שטח קרב\\\": זה הסרט שנטפליקס בחרה לפתוח אתו את השנה?\", \"article_type\": \"ReviewArticle\", \"author_image_square\": \"https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0\", \"brand\": \"HTZ\", \"create_by_AI\": false, \"director\": [\"מיקאל הפסטרום\"], \"distribution_platform\": [\"Netflix\"], \"genre\": [\"אקשן\", \"מדע בדיוני\", \"מלחמה\"], \"image_vertical\": \"https://img.haarets.co.il/bs/0000017f-dbd7-d856-a37f-ffd7d8780000/1d/1a/c6905294909944ae1fec1eed80ff/2166095882.jpg?precrop=1041,1224,x435,y100\", \"movie\": true, \"network\": [\"Netflix\"], \"paywall_status\": \"premium\", \"podcast\": false, \"producer\": [\"אנטוני מקי\"], \"publish_time\": \"2021-01-31\", \"release_year\": 2021, \"review_type\": \"Movie\", \"section_primary\": \"תרבות\", \"section_secondary\": \"קולנוע\", \"section_tertiary\": \"ביקורת סרטים\", \"section_tertiary_id\": \"0000017d-d7fe-d276-a37f-f7fe02280000\", \"short_summary\": \"אקשן עתידני גנרי מנטפליקס עם רובוטים וחיילים אנושיים.\", \"stars\": 2.0, \"summary\": \"בשנת 2036, חייל אמריקאי וסייבורג סודי נשלחים לאזור מלחמה באוקראינה כדי לעצור מרגל רוסי. סרט האקשן העתידני של נטפליקס פותח את שנת 2021 בקול ענות חלושה, סובל מגנריות, תסריט רדוד וליהוק בעייתי.\", \"tag_names\": [\"קולנוע\", \"נטפליקס\"], \"text\": \"לאחר ההכרזה הדרמטית של אולפני וורנר/HBO מקס על שנת הקולנוע הביתית של 2021, והתגובה של תאגיד דיסני על אינסוף תוכן, הגיע תורה של נטפליקס. באמצע ינואר הוכרז הקטלוג של 2021 עם יותר מ–70 סרטים חדשים בפרישה שבועית. הסרטון עמוס הכוכבים נפתח עם גל גדות, דוויין ג'ונסון וריאן ריינולדס, כוכבי סרט הפעולה Red Notice שיגיע מאוחר יותר השנה, והמשיך עם הצצה רגעית לכותרים שאמורים לסקרן. שמות הבמאים דווקא הוצנעו, לכן שווה לספר כי בין היתר יגיעו במשך השנה סרטים חדשים של ג'יין קמפיון, אדם מקיי ופאולו סורנטינו, הכל הודות לנטפליקס. אפשר לומר שהמהלך השיווקי נועד גם להסיח את הדעת מכך שענקית הסטרימינג שוב מעלה את מחיר המנוי, החל בחודש הבא. היבול החדש אמור לכאורה להצדיק זאת, אך הסנונית הראשונה מתוכו מעלה את השאלה העתיקה על איכות לעומת כמות. הראשון שהגיע לשירות מאז ההכרזה הוא \\\"שטח קרב\\\", סרט אקשן עתידני ומלחמתי. השנה היא 2036 ורוסיה מנסה לכבוש את אוקראינה. הדבר מוביל להתערבות אמריקאית וליצירת אזור חיץ בין המדינות. כוח של חיל הנחתים האמריקאי תקוע בין מורדים, מרגלים ואוכלוסייה מקומית. המארינס מסתייעים ברובוטים לוחמים המכונים \\\"גאמפס\\\", אותם מקריבים במידת הצורך כדי לחסוך חיי אדם, ובסיוע אווירי של כטב\\\"מ (או מל\\\"ט כפי שנקראו פעם). הסרט נפתח בסצינת אקשן שבה כוח רגלי נקלע למארב, בעוד בארה\\\"ב יושב מפעיל של כלי טייס בלתי מאויש וצריך לקבל החלטה קשה על עתידם. סגן הארפ (דמסון אידריס) ממרה את פי מפקדיו והעונש שלו הוא לצאת לשטח הקרב. הוא מצוות אל סרן ליאו (אנטוני מקי), שבמהרה מגלה לו את סודו — הוא רק נראה כאדם, אך למעשה הוא אבטיפוס של מכונת מלחמה משוכללת. המשימה של השניים היא לעצור את המרגל הרוסי ויקטור קובל (פילו אסבאק) לפני שיניח את ידיו על מצבור טילים שיכולים להגיע עד ארצות הברית. את הסרט ביים מיקאל הפסטרום השוודי, שכבר הוכיח את עצמו בהוליווד כמוציא לפועל של הפקות חסכוניות — מ\\\"תוכנית בריחה\\\" עם שוורצנגר וסטאלון, ועד \\\"1408\\\" על פי סטיבן קינג. סרטו הנוכחי אמנם לא נראה זול או עשוי רע, האקשן סולידי ומופץ במנות מרוכזות לאורך הצפייה, אבל קצת יותר תקציב היה משפר את המצב. הסרט צולם בהונגריה אבל נראה שלא היה כסף לניצבים, כך שרוב הלוחמה בשטח בנוי מלאכותית ונעדרת תחושת סכנה למקומיים. כאשר רובוטים מצבא א' יורים באנדרואידים מצד ב', האפקטים אמנם סבירים אבל התוצאה כעורה והעניין במתרחש מתפוגג במהירות. כאשר תורם של שחקנים בשר ודם לנווט את קטעי הפעולה או לשאת את המשקל הדרמטי של הסרט, מתחילים געגועים למכונות הלחימה. בתפקידי המשנה משחקים שחקנים מצוינים כמו מייקל קלי (\\\"בית הקלפים\\\"), אמילי ביצ'ם (\\\"ג'ו  ...
# [{"article_id": "0000017f-dbd7-d856-a37f-ffd7d9760000", "article_name": "\"שטח קרב\": זה הסרט שנטפליקס בחרה לפתוח אתו את השנה?", "writer_name": ["אורון שמיר"], "review_type": "Movie", "genre": ["אקשן", "מדע בדיוני", "מלחמה"], "distribution_platform": ["Netflix"], "short_summary": "אקשן עתידני גנרי מנטפליקס עם רובוטים וחיילים אנושיים.", "summary": "בשנת 2036, חייל אמריקאי וסייבורג סודי נשלחים לאזור מלחמה באוקראינה כדי לעצור מרגל רוסי. סרט האקשן העתידני של נטפליקס פותח את שנת 2021 בקול ענות חלושה, סובל מגנריות, תסריט רדוד וליהוק בעייתי.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-dbd7-d856-a37f-ffd7d8780000/1d/1a/c6905294909944ae1fec1eed80ff/2166095882.jpg?precrop=1041,1224,x435,y100", "author_image_square": "https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2021-01-31/ty-article-review/.premium/0000017f-dbd7-d856-a37f-ffd7d9760000"}, {"article_id": "0000017f-ea06-dea7-adff-fbff59160000", "article_name": "\"צבא המתים\": נטפליקס שמה את הכסף על עולם מלא זומבים", "writer_name": ["נתנאל שלומוביץ"], "review_type": "Movie", "genre": ["אקשן", "מדע בדיוני"], "distribution_platform": ["Netflix"], "short_summary": "סניידר: שוד זומבים עתיר אקשן ומדמם בלאס וגאס.", "summary": "זאק סניידר חוזר לשורשי הזומבים בסרט שוד עתיר אקשן בלאס וגאס מוכתמת. נטפליקס בונה יקום קולנועי חדש עם בלגן עקוב מדם, אך לוקה בבניית דמויות.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-ea06-dea7-adff-fbff4b830000/1c/f6/fe0be8ae63ac64cec4d435c1da58/2156939197.jpg?precrop=1155,1354,x92,y11", "author_image_square": "https://img.haarets.co.il/bs/0000017f-da32-d938-a17f-fe3a340e0000/72/0e/b8472abdb5045367467ecaaf71de/1839795353.png?precrop=448,448,x13,y32", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2021-05-24/ty-article-review/.premium/0000017f-ea06-dea7-adff-fbff59160000"}]בטח אחי, מצאתי כמה המלצות לסרטי אקשן חדשים יחסית בנטפליקס שעשויים לעניין אותך.
#
# ראית כבר אחד מהסרטים האלה, או שתרצה שאחפש לך עוד משהו?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513698", "input_tokens": 40887, "output_tokens": 64, "rag_speed": 1.42091703414917, "llm_speed": 6.085162878036499, "total_time": 7.816891193389893}
# {"asctime": "2025-05-07 12:35:40,187", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Loaded history for user 1945513698 from Redis."}
# ====================
# Second Question: תוכל להשוות בין הסרט שהצעת לבין ‘Seven’ מבחינת עלילה וטון?
# Warning: there are non-text parts in the response: ['function_call'],returning concatenated text result from text parts,check out the non text parts for full response from model.
# {"asctime": "2025-05-07 12:35:48,741", "name": "UNKNOWN_APP_NAME_logger", "levelname": "INFO", "message": "query=Seven, streaming=[], genres=[], media_type=movie"}
# {"asctime": "2025-05-07 12:35:49,368", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Translated query to Hebrew: 'שבע'"}
# {"asctime": "2025-05-07 12:35:50,019", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Raw search_results for cost tracking: [{\"actors\": [\"רייצ'ל סנוט\", \"פולי דרייפר\", \"פרד מלמד\", \"מולי גורדון\", \"דני דפרארי\", \"דיאנה אגרון\"], \"article_id\": \"0000017f-e9b7-d639-af7f-e9f736c30000\", \"article_name\": \"\\\"שבעה בייבי\\\": קומדיה שחורה משחור על זהות מינית, מסורת יהודית וסלנג יידישאי\", \"article_type\": \"ReviewArticle\", \"author_image_square\": \"https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0\", \"brand\": \"HTZ\", \"create_by_AI\": false, \"director\": [\"אמה סליגמן\"], \"distribution_platform\": [\"בתי קולנוע\"], \"genre\": [\"דרמה\", \"קומדיה\"], \"image_vertical\": \"https://img.haarets.co.il/bs/0000017f-e9b7-d639-af7f-e9f72be30000/1b/0d/9f58ca4f6f73ff101630a0c67a38/3937296173.jpg?precrop=919,1081,x1281,y157\", \"movie\": true, \"network\": [\"בתי קולנוע\"], \"paywall_status\": \"premium\", \"podcast\": false, \"producer\": null, \"publish_time\": \"2021-06-09\", \"release_year\": 2020, \"review_type\": \"Movie\", \"section_primary\": \"תרבות\", \"section_secondary\": \"קולנוע\", \"section_tertiary\": \"ביקורת סרטים\", \"section_tertiary_id\": \"0000017d-d7fe-d276-a37f-f7fe02280000\", \"short_summary\": \"קומדיה שחורה על שבעה, שקרים, זהות מינית וקהילה יהודית.\", \"stars\": 3.5, \"summary\": \"במהלך שבעה בבית משפחה יהודית, צעירה ביסקסואלית נלכדת ברשת שקריה כשהיא פוגשת את האקסית והשוגר-דדי שלה. קומדיה שחורה שנונה ומותחת על זהות, סודות ונירוזות משפחתיות.\", \"tag_names\": null, \"text\": \"מעטים הסרטים שניתן להקרין גם בפסטיבלי קולנוע יהודי וגם בפסטיבלי קולנוע גאה. אלא שבשנה החולפת היו שניים כאלה, באורך זהה, נקודת מוצא עלילתית דומה, ואותה שחקנית ראשית. האחד הוא \\\"טהרה\\\", על שתי תלמידות בבית ספר יהודי שמתקרבות רומנטית דווקא אחרי לוויה של בת כיתתן. האחר הוא \\\"שבעה בייבי\\\", שבו צעירה יהודיה וקווירית הולכת ומסתבכת במהלך ניחום אבלים — והוא יוקרן מחר (חמישי) בסינמטק תל אביב במסגרת \\\"שבוע הגאווה\\\", שלוחה קיצית של פסטיבל הקולנוע הגאה שייערך בנובמבר. \\\"שבעה בייבי\\\", שביימה אמה סליגמן הקנדית בתקציב צנוע, היה אמור לערוך את בכורתו במארס 2020 בפסטיבל SXSW בטקסס, שם הוקרן לפני כשלוש שנים סרטה הקצר בעל אותו השם. אולם הפסטיבל בוטל בגלל מגפת הקורונה והסרט הוקרן לבסוף בפסטיבלים אונליין (בישראל הוא הוקרן לראשונה במהדורת האונליין של פסטיבל הקולנוע היהודי בירושלים), אך לא תפס תאוצה עד השבועות האחרונים. פתיחתם של בתי הקולנוע בערים גדולות וחובבות קולנוע מסוגו, דוגמת ניו יורק, סייעה לסרט לצבור אהדה וביקורות חיוביות. וכך הוא מגיע אל הבכורה הישראלית שלו על המסך הגדול – כסרט קטן אך מדובר ומהולל. במרכז הסרט עומדת דניאל (רייצ'ל סנוט), אותה אנו פוגשים לראשונה ביום עבודה: היא מספקת מינית את השוגר־דדי שלה (דני דפרארי), אבל לא נהנית בעצמה. עבורה הוא אפילו לא סקס סתמי, אלא לקוח. לאחר מכן, לבקשת הוריה (פולי דרייפר ופרד מלמד) היא מגיעה לאירוע קהילתי, ניחום אבלים, כאשר היא אפילו לא יודעת על מי יושבים שבעה. מנקודה זו, הברוך רק מתעצם. מתברר שהאקסית המיתולוגית והמוצלחת (מולי גורדון) גם היא בין המנחמים. וגם השוגר־דדי מן הפתיחה צץ בדלת ואחריו אשתו השיקסע (דיאנה אגרון) והתינוק שלהם, שלא מפסיק לבכות. דניאל מנסה להתחמק או להתעמת עם מי שאורב לה בכל בופה ובוחן את גזרתה, אך בעיקר מסתבכת במבוך השקרים שטוותה — בקשר למקורות ההכנסה שלה, ללימודיה ולנטייתה המינית. להיות צעירה יהודייה ביסקסואלית שלומדת מגדר ומשלימה הכנסה בתור לא־נעים־לומר־מה, זה לא א גרויסע מציאה. בטח לא באמצע שבעה.  סליגמן כתבה את הסיפור של דניאל כקומדיית מבוכה, אבל מביימת אותו כמותחן אימה. עם זאת, הסרט לא מנסה לקרוע מצחוק או להפחיד את הצופים, והשילוב הזה לא בהכרח מקורי (כפי שהדגים לאחרונה \\\"תברח\\\"), אבל עובד רוב הזמן. התסריט דחוס התרחשויות גורליות, מה שמוביל לעתים לקיצורי דרך או תחושת חזרתיות, אבל הדגש הוא על האווירה. שורות הדיאלוג מצחיקות במידה ומתובלות בסלנג יידישאי, אך כיוון שמדובר באירוע טרגי צבע ההומור הוא שחור משחור. המרכיב הקומי בסיטואציות הפולשניות שנוצרות בבית הצפוף משמש בעיקר לביקורת חברתית: בין אם על הצורך בפרטיות מול הרצון לבחוש בענייני הזולת, על האו ...
# [{"article_id": "0000017f-e9b7-d639-af7f-e9f736c30000", "article_name": "\"שבעה בייבי\": קומדיה שחורה משחור על זהות מינית, מסורת יהודית וסלנג יידישאי", "writer_name": ["אורון שמיר"], "review_type": "Movie", "genre": ["דרמה", "קומדיה"], "distribution_platform": ["בתי קולנוע"], "short_summary": "קומדיה שחורה על שבעה, שקרים, זהות מינית וקהילה יהודית.", "summary": "במהלך שבעה בבית משפחה יהודית, צעירה ביסקסואלית נלכדת ברשת שקריה כשהיא פוגשת את האקסית והשוגר-דדי שלה. קומדיה שחורה שנונה ומותחת על זהות, סודות ונירוזות משפחתיות.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-e9b7-d639-af7f-e9f72be30000/1b/0d/9f58ca4f6f73ff101630a0c67a38/3937296173.jpg?precrop=919,1081,x1281,y157", "author_image_square": "https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2021-06-09/ty-article-review/.premium/0000017f-e9b7-d639-af7f-e9f736c30000"}, {"article_id": "0000018a-6e5a-dfd9-ad9f-effe9ab40000", "article_name": "\"שבע ברכות\" הוא סרט חכם ומרתק על המפגש בין התרבויות האשכנזית והמזרחית", "writer_name": ["שני ליטמן"], "review_type": "Movie", "genre": ["דרמה"], "distribution_platform": ["בתי קולנוע"], "short_summary": "דרמה משפחתית חכמה ומרתקת עם משחק מצוין והומור.", "summary": "שבע ברכות היא דרמה משפחתית מרתקת על מפגש תרבויות ודיכוי. עם כתיבה חכמה, רגעי הומור ושנינות לצד תכנים קשים, הסרט מציג מערכות יחסים מורכבות ונהנה מרגעי משחק עוצמתיים.", "image_vertical": "https://img.haarets.co.il/bs/0000018a-6e5a-dfd9-ad9f-effe99ac0000/cc/0d/21ed40714e20b9693887a069111c/53428624.JPG?precrop=1701,2000,x533,y0", "author_image_square": "https://gif.haarets.co.il/bs/00000190-6e54-dbfd-a5d1-eed787350001/ee/13/67f9ddd1443ab30a88aef14ae83b/shani.gif?precrop=1266,1266,x67,y33", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2023-09-07/ty-article-review/.premium/0000018a-6e5a-dfd9-ad9f-effe9ab40000"}]אני מבין שאתה רוצה להשוות בין סרט אקשן שהמלצתי עליו לבין הסרט 'Seven' מבחינת עלילה וטון.
#
# ניסיתי למצוא מידע שיאפשר לי לעשות את ההשוואה הזו עבורך, אבל המידע שיש לי על הסרט 'Seven' לא מתאים לצורך ההשוואה הספציפית שביקשת. לכן, לצערי, אני לא יכול כרגע להשוות בין הסרטים בדרך שרצית.
#
# אשמח להמליץ לך על סרטים או סדרות אחרות, או לספר לך עוד על סרטים שיש לי עליהם מידע. יש ז'אנרים נוספים שמעניינים אותך, או אולי תרצה המלצה על סרט דומה לאחד מהסרטים שדיברנו עליהם?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513698", "input_tokens": 86601, "output_tokens": 207, "rag_speed": 1.278144121170044, "llm_speed": 14.793026685714722, "total_time": 16.323590993881226}
# 2025-05-07 12:35:57.456 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-07 12:35:57.456 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# {"asctime": "2025-05-07 12:35:57,527", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "No history found for user 1945513699 in Redis."}
# ====================
# Article ID:
# Question: מחפשת סדרה קלילה ומצחיקה, קומדיה כזאת, לא משנה לי באיזה שירות סטרימינג.
# Warning: there are non-text parts in the response: ['function_call'],returning concatenated text result from text parts,check out the non text parts for full response from model.
# {"asctime": "2025-05-07 12:35:59,299", "name": "UNKNOWN_APP_NAME_logger", "levelname": "INFO", "message": "query=סדרה קלילה ומצחיקה, streaming=[], genres=['קומדיה'], media_type=series"}
# {"asctime": "2025-05-07 12:36:00,600", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Raw search_results for cost tracking: [{\"actors\": [\"גורי אלפי\", \"יובל סמו\", \"אלי יצפאן\", \"תיקי דיין\", \"גילה אלמגור\"], \"article_id\": \"0000017f-debf-d3ff-a7ff-ffbffd8d0000\", \"article_name\": \"\\\"שקופים\\\" היא בונבוניירה של צחוק ועליבות. רוצו לראות\", \"article_type\": \"ReviewArticle\", \"author_image_square\": \"https://img.haarets.co.il/bs/0000017d-d244-d17a-af7f-d7e4a4ea0000/c8/93/875d80ed963046da792485007f7e/982406958.png?precrop=1492,1492,x0,y0\", \"brand\": \"HTZ\", \"create_by_AI\": false, \"director\": [\"אלי בן דוד\"], \"distribution_platform\": [\"HOT\"], \"genre\": [\"קומדיה\"], \"image_vertical\": \"https://img.haarets.co.il/bs/0000017f-debf-d3ff-a7ff-ffbffcb20000/19/3f/c0cb936e4d23a8e193c69475c651/3078944624.jpg?precrop=919,1080,x639,y0\", \"movie\": true, \"network\": [\"HOT\"], \"paywall_status\": \"superlock\", \"podcast\": false, \"producer\": [\"אלי בן דוד\", \"אדר מירום\", \"עמרי עמית\"], \"publish_time\": \"2021-01-18\", \"review_type\": \"Series\", \"section_primary\": \"תרבות\", \"section_secondary\": \"טלוויזיה\", \"section_tertiary\": null, \"section_tertiary_id\": null, \"short_summary\": \"בונבוניירה של צחוק ועליבות, ליהוק אלוהי וטקסטים מצוינים.\", \"stars\": 5.0, \"summary\": \"סדרת המערכונים של HOT בהובלת גורי אלפי ויובל סמו. עם ליהוק אלוהי, טקסטים שנונים ובימוי משובח, הסדרה מאזנת בין אמפתיה לדמויות שקופות חברתית לבין מבט ציני על טבע האדם. בונבוניירה של צחוק ועליבות.\", \"tag_names\": null, \"text\": \"\\\"בעולם שלנו צוחק מי שעוד לא בוכה\\\", כתב פעם חנוך לוין והמשפט מופיע בכתובית בפרק השני של \\\"שקופים\\\". אז מה זה אומר עלי, שצחקתי בקול גדול במערכון שבו דודי (יובל סמו), מאבטח עני בגיל העמידה שגר עם אמא וערימת גופיות מאפירות, מתקמבן עם הומלס בחצר השיכון המוזנח וביחד הם מצליחים לשבור את ליבו של השליח מ\\\"וולט\\\" בסיפור אנושי מזעזע ודמיוני, ובסוף השליח משלשל לקופסת השימורים 50 שקל, ודודי וההומלס מתחלקים בזכייה? בסופו של דבר, זה אומר שאני לא שם: לא מאבטחת, לא הומלסית, יכולה לבחור היכן אגור ולא נסמכת על סופגניות קרות שמחלקים רבנים בבית חולים כדי לחגוג חנוכה. ההנחה מאחורי \\\"שקופים\\\", סדרת מערכונים קומית עם ליהוק אלוהי, טקסטים מצוינים, בימוי משובח, צילום מעולה וריאליסטי ואפילו מוזיקה טובה במיוחד, היא שרוב הצופים אינם בהכרח אנשים מוחלשים סוציו־אקונומית, לא כמו הדמויות שמתרוצצות על המסך — ובכל זאת, כולנו מכירים אותן. ודמויות דומות להן. מי מתוך אמפתיה וזעם אזרחי, מי מהתנכרות מוחלטת ומחשבה שניחשול חברתי כתוצאה מעוני הוא גזירת גורל, או עדות ללוזריות של העניים.  והנחה שנייה, שמתרגמת את העליבות לדחקות, היא שכל בני האדם ניחנו ביצרים רעים, כולם מסוגלים לצחוק למראה אדם מחליק על קליפת בננה וכולם, בהינתן מצבים קיצוניים, יכולים גם להצטייד בקליפה ולהניח אותה באופן אסטרטגי בדרכו של הזולת. בין האמפתיה והזעם לבין ההכרה המפוכחת, החנוך־לוינית, שכולנו חארות, עלובים, חסרי תקווה ועוד מעט נמות — צריך כישרון לא מבוטל כדי ליצור את היופי שמצאתי בשלושת פרקי הסדרה בהם צפיתי. אם לא היה ברור עד כה: רוצו לראות. שתי דמויות מובילות, אביאל ודודי — גורי אלפי ויובל סמו, הראשון מתפקד מעולה מחוץ לאזור הנוחות שלו והשני מגיע עם קילומטרז' של \\\"אשר\\\", נהג המונית מ\\\"ארץ נהדרת\\\", כולל המבטא — משמשות כמסגרת לסיטואציות מחיי העבודה: מברכים לשלום את כל עובדי המגדל ההייטקי המנוכר, לא נענים. מבקשים העלאה בשכר, נתקלים בחזיר קפיטליסטי בדמותו המלבבת של אלי יצפאן, שמתעלה במשחקו כשכותבים לו טקסטים טובים ומפגין יכולות קומיות מצוינות. מתקמבנים, משקרים, מנסים לקושש לעצמם מעט כבוד והערכה, רבים, מתפייסים, סובלים — בלי ספויילרים, מנעד המערכונים עובר בין סיטואציות שבהן הלב נצבט לבין כאלה שמשחררות צחוקים, לעתים לאידן של הדמויות ולעתים לגמרי איתן. תיקי דיין בתפקיד סימונה, השדכנית של הלוזרים הנצחיים שמוכנה להבטיח \\\"בחורה שגרה ברמלה, עם שותפות, עושה כושר כל יום, אוהבת לטייל בשמש\\\" ובעצם מציעה לאביאל אסירה — נושאת על פנים חפים מאיפור גם את העליבות וגם את הרוע השיווקי, בעולם שמוכר לכולם אשליות. גילה אלמגור, בתפקיד אמו של דודי, מוכיחה שוב שאין דבר כזה תפקידים קטנים. \\\"שקופים\\\" מכוונת גבוה. הגם שהמעברים בין המערכונים מתהדרים ב ...
# [{"article_id": "0000017f-debf-d3ff-a7ff-ffbffd8d0000", "article_name": "\"שקופים\" היא בונבוניירה של צחוק ועליבות. רוצו לראות", "writer_name": ["אריאנה מלמד"], "review_type": "Series", "genre": ["קומדיה"], "distribution_platform": ["HOT"], "short_summary": "בונבוניירה של צחוק ועליבות, ליהוק אלוהי וטקסטים מצוינים.", "summary": "סדרת המערכונים של HOT בהובלת גורי אלפי ויובל סמו. עם ליהוק אלוהי, טקסטים שנונים ובימוי משובח, הסדרה מאזנת בין אמפתיה לדמויות שקופות חברתית לבין מבט ציני על טבע האדם. בונבוניירה של צחוק ועליבות.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-debf-d3ff-a7ff-ffbffcb20000/19/3f/c0cb936e4d23a8e193c69475c651/3078944624.jpg?precrop=919,1080,x639,y0", "author_image_square": "https://img.haarets.co.il/bs/0000017d-d244-d17a-af7f-d7e4a4ea0000/c8/93/875d80ed963046da792485007f7e/982406958.png?precrop=1492,1492,x0,y0", "url": "https://www.haaretz.co.il/gallery/television/2021-01-18/ty-article-review/.highlight/0000017f-debf-d3ff-a7ff-ffbffd8d0000"}, {"article_id": "0000017f-e1d8-df7c-a5ff-e3faf9820000", "article_name": "\"תרגיע\": לארי דיוויד לא מפחד מתקינות פוליטית ומהרהר על הזדקנות ומוות", "writer_name": ["חן חדד"], "review_type": "Series", "genre": ["קומדיה"], "distribution_platform": ["HOT", "Yes", "נקסט טיוי"], "short_summary": "לארי דיוויד מצחיק בחוצפה, לא פוחד מכלום.", "summary": "\"תרגיע\" עדיין מצחיקה בטירוף בעונתה ה-11. לארי דיוויד מנפץ מוקשי תקינות פוליטית בהנאה, ומהרהר בהומור על הזדקנות ומוות. איכויות נדירות לקומדיה בעידן הזה.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-e1d8-df7c-a5ff-e3faf8a10000/56/c4/2af354be1cbfcb3ba56474445397/1895925891.jpg?precrop=865,1016,x503,y16", "author_image_square": "https://img.haarets.co.il/bs/0000017f-da31-d718-a5ff-fab5e98c0000/fd/01/b40e6111d78f7c7a20a7e88c27fc/3306098334.jpg?precrop=728,728,x0,y0", "url": "https://www.haaretz.co.il/gallery/television/tv-review/2021-10-26/ty-article-review/.highlight/0000017f-e1d8-df7c-a5ff-e3faf9820000"}]נהדר, חיפשתי עבורך המלצות לסדרות קומדיה קלילות ומצחיקות.
#
# אני מקווה שהמלצות אלו יעזרו לך למצוא משהו שכיף לראות. יש עוד סוגים של קומדיות שאת אוהבת? או אולי ז'אנרים אחרים שמעניינים אותך?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513699", "input_tokens": 29926, "output_tokens": 86, "rag_speed": 1.3008768558502197, "llm_speed": 3.6487762928009033, "total_time": 5.191309213638306}
# {"asctime": "2025-05-07 12:36:03,308", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Loaded history for user 1945513699 from Redis."}
# ====================
# Second Question: האם בסרט שהמלצת יש ייצוג נשי משמעותי? צטט ביקורות שמדברות על כך.
# אני מבין שחשוב לך ייצוג נשי בסרטים ובסדרות. עם זאת, חשוב לי להבהיר שבהמלצה האחרונה שלי התייחסתי לשתי סדרות קומדיה, "שקופים" ו"תרגיע", ולא לסרט.
#
# מכיוון שהשאלה שלך מתייחסת לסרט ספציפי שהמלצתי, ואני לא המלצתי על סרט בשיחתנו, אין לי כרגע מידע רלוונטי מתוך הביקורות שמדבר על ייצוג נשי בסרט מסוים. כל המידע שלי מגיע מהביקורות והמאמרים ששיתפתי.
#
# יש משהו ספציפי שאת מחפשת לראות שחשוב לך שיהיה בו ייצוג נשי בולט? אשמח לנסות למצוא לך המלצות מתאימות!{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513699", "input_tokens": 30041, "output_tokens": 207, "rag_speed": 0, "llm_speed": 3.936755895614624, "total_time": 4.105183839797974}
# 2025-05-07 12:36:08.201 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-07 12:36:08.202 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# {"asctime": "2025-05-07 12:36:08,274", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "No history found for user 1945513700 in Redis."}
# ====================
# Article ID:
# Question: מה כדאי לראות עכשיו ביס פלוס? בא לי איזה משהו מתח טוב.
# Warning: there are non-text parts in the response: ['function_call'],returning concatenated text result from text parts,check out the non text parts for full response from model.
# {"asctime": "2025-05-07 12:36:09,917", "name": "UNKNOWN_APP_NAME_logger", "levelname": "INFO", "message": "query=מה כדאי לראות עכשיו ביס פלוס? בא לי איזה משהו מתח טוב., streaming=['Yes'], genres=['מותחן'], media_type=None"}
# {"asctime": "2025-05-07 12:36:10,547", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Raw search_results for cost tracking: [{\"actors\": [\"ג'ולס וילקוקס\", \"מארק מנצ'אקה\", \"אנתוני הילד\"], \"article_id\": \"0000017f-e651-dea7-adff-f7fbfd460000\", \"article_name\": \"\\\"לבד\\\" מוכיח: די במעט אמצעים כדי שאימה תזחל במורד הצוואר שלכם\", \"article_type\": \"ReviewArticle\", \"author_image_square\": \"https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0\", \"brand\": \"HTZ\", \"create_by_AI\": false, \"director\": [\"ג'ון היימס\"], \"distribution_platform\": [\"Yes\"], \"genre\": [\"מותחן\", \"אימה\"], \"image_vertical\": \"https://img.haarets.co.il/bs/0000017f-e651-dea7-adff-f7fbf3c90000/23/85/31595c5f7373cb6612384ced708e/4055129890.jpg\", \"movie\": true, \"network\": [\"Yes\"], \"paywall_status\": \"premium\", \"podcast\": false, \"producer\": [\"מטיאס אולסון\"], \"publish_time\": \"2021-03-31\", \"release_year\": 2020, \"review_type\": \"Movie\", \"section_primary\": \"תרבות\", \"section_secondary\": \"קולנוע\", \"section_tertiary\": \"ביקורת סרטים\", \"section_tertiary_id\": \"0000017d-d7fe-d276-a37f-f7fe02280000\", \"short_summary\": \"מותחן אימה מינימליסטי ויעיל שמצליח לזחול מתחת לעור.\", \"stars\": 3.5, \"summary\": \"עם מעט אמצעים וגיבורה תושייה, מותחן האימה 'לבד' משתמש בזוויות צילום ורעש טבעי כדי ליצור מתח מקסימלי. הוא עולה על מגבלותיו ומספק חוויה מטלטלת.\", \"tag_names\": null, \"text\": \"כשמדברים על היעדרם של שוברי קופות מחיינו בשנה האחרונה, לרוב לא מתכוונים בהכרח לקולנוע אימה. אבל גם סרטי אימה ומתח קיצוניים יותר או פחות נחשבים בארה״ב לאירועים חברתיים. גם בז'אנרים אלה, רוב השמות הגדולים שתוכננו לצאת לאקרנים נדחו עד שבתי הקולנוע ישובו לפעילות מלאה. שוחרי המתח והאימה נאלצו להסתפק בסרטים צנועים יותר שמילאו את החלל. אחד מהם הוא \\\"לבד\\\" — שם שבאופן משונה הוצמד לכמה סרטי מתח השנה — הזמין כעת ביס VOD. מדובר ברימייק לסרט שוודי מלפני עשור בשם Försvunnen ׁ(בתרגום מילולי, \\\"חסר\\\"), שיוצרו מטיאס אולסון כתב גם את הגרסה האמריקאית החדשה. מלאכת הבימוי הופקדה בידי ג'ון היימס, שמצליח להרשים כבר בפתיח. הצופים פוגשים את ג'סיקה (ג'ולס וילקוקס) כשהיא מעמיסה בחפצים את רכבה ואת הנגרר ששכרה. אף מילה לא נאמרת בדקות הראשונות של הסרט, אבל ברור שהיא עוזבת מקום אחד בדרכה הארוכה למקום אחר. מפלס החרדה מתחיל לטפס מעט אחר כך, בזכות סיטואציה שמוכרת לכל נהג — היתקלות ברכב שנוסע באופן שמרתיח את הדם, מאט מאוד ומפריע לעקוף, אולי אפילו מחפש מריבה. הסיפור של ג'סיקה נחשף בהדרגה והטראומה שעליה היא מתגברת עשויה להיות המקור לחרדות שלה בכביש, אבל ככל שנוקפות הדקות מתברר כי אותו נהג כנראה באמת מנסה להזיק לה. הידיעה הזו הופכת את הסרט ממותחן פסיכולוגי למסע היחלצות רווי אימה מפני כוח זדוני שנראה יומיומי.  כמו בפתיחה, לכל אורך הסרט משכילים היוצרים ליצור מתח כאילו מכלום. בחינה מדוקדקת מגלה מקסום של הכלים הקולנועיים הפשוטים והיעילים ביותר. בכל הקשור ליצירת מתח ולחץ, לפעמים מיקום המצלמה חשוב לא פחות ממה שהיא מצלמת. הצילום של פדריקו ורארדי, שעבד עם הבמאי גם בסדרה \\\"אומת הזומבים\\\" (נטפליקס), הוא אחת ממעלותיו של הסרט. כאשר הדיאלוגים מגיעים לבסוף והעלילה מתחילה להתבהר, נדמה שהסרט פוסע בנתיבים מוכרים למדי, אך העשייה הקולנועית מרוממת אותו מעל לנקודת המוצא השגרתית יחסית. מאחר שהתכנון והביצוע של הצילום מוצלחים דיים, קל להתרשם לטובה משאר האלמנטים. רוב המתח בסרט נבנה בעריכה ובפסקול, במלאכת החיבור של נקודות המבט העקומות והתמונות המערערות. כבר מאותה תקרית בכביש ברור שהסרט לא מבזבז זמן ונע קדימה בקצב, מבלי להתפשר על הצגה בהירה של המתרחש. מצד אחר, היוצרים יודעים מתי למתוח רגעים שיעוררו תגובה פיזית בקהל. הם גם יודעים מתי להזרים פנימה מוזיקה מבשרת רעות ומתי להישאר עם הרעש הטבעי של כל סיטואציה — נהיגה לילית, רחשי יער, נהר מרוחק שהשאון שלו הולך ומתגבר ככל שמתקרבים אליו. מדהים כמה שזה אפקטיבי, ולכן בשום אופן לא מורגש מחסור בגימיקים למיניהם או געגוע לאותן הבהלות זולות שנהפכו לנפוצות בקולנוע האימה של המאה ה–21. היימס הוא נצר למשפחת קולנוענים שהחוט המקשר ביניהם הוא ז'אן־קלוד ואן דאם. בשנות ה–90 היה זה האב, פיטר היימס, שביים את הכוכב הבלגי־יהודי בסרטים \\\"טיימקופ\ ...
# [{"article_id": "0000017f-e651-dea7-adff-f7fbfd460000", "article_name": "\"לבד\" מוכיח: די במעט אמצעים כדי שאימה תזחל במורד הצוואר שלכם", "writer_name": ["אורון שמיר"], "review_type": "Movie", "genre": ["מותחן", "אימה"], "distribution_platform": ["Yes"], "short_summary": "מותחן אימה מינימליסטי ויעיל שמצליח לזחול מתחת לעור.", "summary": "עם מעט אמצעים וגיבורה תושייה, מותחן האימה 'לבד' משתמש בזוויות צילום ורעש טבעי כדי ליצור מתח מקסימלי. הוא עולה על מגבלותיו ומספק חוויה מטלטלת.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-e651-dea7-adff-f7fbf3c90000/23/85/31595c5f7373cb6612384ced708e/4055129890.jpg", "author_image_square": "https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2021-03-31/ty-article-review/.premium/0000017f-e651-dea7-adff-f7fbfd460000"}, {"article_id": "0000017f-e4e7-df2c-a1ff-fef7bca60000", "article_name": "\"לברוח\": בסדרה הזאת יש קסם רומנטי כמו בכל דבר שפיבי וולר־ברידג' נוגעת בו", "writer_name": ["חן חדד"], "review_type": "Series", "genre": ["דרמה", "קומדיה", "מותחן"], "distribution_platform": ["HOT", "Yes", "נקסט טיוי"], "short_summary": "סדרה רומנטית־מותחת עם כימיה אדירה וקסם ממכר.", "summary": "הסדרה מתחילה כקומדיה רומנטית שנונה, הופכת למותחן אפל ומרתק. עם כימיה אדירה וקסם של וולר־ברידג', 'לברוח' יוצרת אינטימיות מיידית ומשאירה חשק עז לעוד.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-e4e7-df2c-a1ff-fef7b5420000/01/e5/e5de5ada54c400a88e1f7e3bcf4f/1345534747.jpg?precrop=1015,1192,x107,y173", "author_image_square": "https://img.haarets.co.il/bs/0000017f-da31-d718-a5ff-fab5e98c0000/fd/01/b40e6111d78f7c7a20a7e88c27fc/3306098334.jpg?precrop=728,728,x0,y0", "url": "https://www.haaretz.co.il/gallery/television/tv-review/2020-04-13/ty-article-review/.highlight/0000017f-e4e7-df2c-a1ff-fef7bca60000"}]מצאתי שתי המלצות שיכולות לעניין אותך בז'אנר המתח ביס פלוס: "לבד" וגם "לברוח".
#
# ספר לי אם אחת מהן נשמעת מעניינת, או שאולי תרצה המלצות בז'אנרים אחרים?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513700", "input_tokens": 34343, "output_tokens": 71, "rag_speed": 0.6306328773498535, "llm_speed": 4.818804979324341, "total_time": 5.691244125366211}
# {"asctime": "2025-05-07 12:36:14,580", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Loaded history for user 1945513700 from Redis."}
# ====================
# Second Question: מהן שלוש נקודות הביקורת העיקריות שהוזכרו נגד הסרט במקורות שהבאת?
# על פי הביקורת על הסרט "לבד", שלוש נקודות הביקורת העיקריות שהועלו הן:
#
# 1.  העלילה פוסעת בנתיבים מוכרים למדי ואינה מפתיעה.
# 2.  המניעים של הרודף מעט סתומים, ויש חוסר בברק עלילתי.
# 3.  הסרט אינו נחשב ל"סרט גדול", אלא כזה שיכול "לסגור פינה" עד שיגיעו סרטים מטלטלים יותר.
#
# האם תרצה לדעת עוד פרטים על הביקורת או אולי על סרטי מתח אחרים?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513700", "input_tokens": 34451, "output_tokens": 160, "rag_speed": 0, "llm_speed": 4.160546064376831, "total_time": 4.307156324386597}
# 2025-05-07 12:36:19.525 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-07 12:36:19.526 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# {"asctime": "2025-05-07 12:36:19,597", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "No history found for user 1945513701 in Redis."}
# ====================
# Article ID:
# Question: יש לך המלצה לסרט דרמה איכותי? עדיף משהו שזמין בהוט.
# Warning: there are non-text parts in the response: ['function_call'],returning concatenated text result from text parts,check out the non text parts for full response from model.
# {"asctime": "2025-05-07 12:36:21,006", "name": "UNKNOWN_APP_NAME_logger", "levelname": "INFO", "message": "query=המלצה לסרט דרמה איכותי, streaming=['HOT'], genres=['דרמה'], media_type=movie"}
# {"asctime": "2025-05-07 12:36:21,645", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Raw search_results for cost tracking: [{\"actors\": [\"אנדרו סקוט\", \"פול מסקל\", \"ג'יימי בל\", \"קלייר פוי\"], \"article_id\": \"00000190-5479-ddd9-a1f1-d6fb66e80000\", \"article_name\": \"\\\"כולנו זרים\\\" לא הגיע לבתי הקולנוע בישראל – וזה פספוס ענק\", \"article_type\": \"ReviewArticle\", \"author_image_square\": \"https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0\", \"brand\": \"HTZ\", \"create_by_AI\": false, \"director\": [\"אנדרו הייג\"], \"distribution_platform\": [\"Disney+\", \"Apple TV+\", \"HOT\", \"Yes\"], \"genre\": [\"דרמה\"], \"image_vertical\": \"https://img.haarets.co.il/bs/00000190-5479-ddd9-a1f1-d6fb64760000/c7/68/11cae054464ab00c35d5fc055924/57380633.JPG?precrop=918,1080,x301,y0\", \"minutes\": 105, \"movie\": true, \"network\": [\"Disney+\", \"Apple TV+\", \"HOT\", \"Yes\"], \"paywall_status\": \"premium\", \"podcast\": false, \"producer\": [\"אנדרו הייג\"], \"publish_time\": \"2024-06-26\", \"release_year\": 2023, \"review_type\": \"Movie\", \"section_primary\": \"תרבות\", \"section_secondary\": \"קולנוע\", \"section_tertiary\": \"ביקורת סרטים\", \"section_tertiary_id\": \"0000017d-d7fe-d276-a37f-f7fe02280000\", \"short_summary\": \"סיפור אינטימי על אובדן ובדידות, עם משחק מרהיב של אנדרו סקוט.\", \"stars\": 4.0, \"summary\": \"דרמה נוגה ומרגשת על תסריטאי בודד הפוגש את הוריו המתים ונכנס למערכת יחסים עם שכן מסתורי. סרט אינטימי על אובדן, בדידות וסליחה, עם הופעות משחק יוצאות דופן ובימוי רגיש.\", \"tag_names\": null, \"text\": \"חודש הגאווה, שנחגג לרוב בססגוניות לאורך כל יוני, היה צנוע השנה. גם מבחינת הקולנוע, ההיצע היה פחוּת מהרגיל מבחינת כמות ונסמך בעיקר על יוזמות — כמו סופשבוע גאווה בסינמטק תל אביב, מבית הפסטיבל הבינלאומי לקולנוע גאה. המהדורה האחרונה של הפסטיבל, שהתקיימה בחורף, נפתחה עם \\\"כולנו זרים\\\", שהגיע מעוטר ומילא אולמות. מאז הגיח מספר פעמים להקרנות בסינמטקים, וזה כמה שבועות שהוא זמין בשירות הסטרימינג דיסני+. החודש אפשר כבר לשכור אותו בתשלום נוסף אצל ספקיות התוכן הישראליות (יס, הוט, סלקום טיוי ופרטנר טיוי) וגם באפל טיוי+. כלומר, בשלה העת לשוב ולהלל אותו. מדובר לא רק באחד הסרטים היפים והנוגים של השנה החולפת, אלא גם בסרט קווירי התואם את תחושת המלנכוליה הכללית של התקופה. אודות העלילה כדאי לדעת את המינימום, אפילו הטריילר מלא ספוילרים. אפשר גם להחליט לצפות בסרט מבלי לדעת דבר מלבד זהות היוצר והמשתתפים. הבמאי־תסריטאי הוא אנדרו הייג הבריטי, שחתום על יצירות מרטיטות נפש כמו \\\"סוף שבוע\\\" או \\\"45 שנים\\\". בתפקיד הראשי זכה אנדרו סקוט, הלא הוא \\\"הוט פריסט\\\" מהעונה השנייה של \\\"פליבג\\\" ולאחרונה גם \\\"ריפלי\\\" של נטפליקס. סביבו חגים פול מסקל (\\\"אחרי השמש\\\"), ג'יימי בל (\\\"סקין\\\") וקלייר פוי (\\\"הכתר\\\").  סביר שבזמן הסרט תצפו בשחקנים הללו דרך מסך של דמעות ותאזינו להם מבעד לקינוחי אף תדירים, וגם את זה ראוי לדעת לפני הצפייה — זה לא סתם סרט מדמיע, הוא מחולל בכי של ממש. יצא לי לצפות בו לראשונה בהקרנת עיתונאים בפסטיבל ניו יורק בספטמבר האחרון, ואינני זוכר \\\"פסקול\\\" כזה לסרט קולנוע כבר שנים — מהתייפחויות חרישיות ועד נהי מר, מהתחלה ועד הסוף. במובן זה בלבד, אולי עדיף להתפרק לבד בבית מאשר מוקף זרים באולם חשוך. סקוט מגלם את אדם, תסריטאי במשבר. את שלוות מחסום הכתיבה שלו מפרה אזעקת תרגול בבניין רב הקומות הלונדוני בו הוא מתגורר. המקום נדמה נטוש למעט שכן (מסקל) שעושה לו עיניים — ונדחה, לפחות בהתחלה. אדם מנסה לכתוב תסריט שמתחיל באזור פרברי יותר של אנגליה, בשנת 1987. הוא מחפש השראה במזכרות ישנות ולבסוף יוצא את פאתי העיר ולוקח רכבת אל בית ילדותו, היכן שמצפה לו הפתעה: שני הוריו (בל ופוי) שם, אבל הם בערך בגילו. האם הוא מדמיין אותם או שמתרחש אירוע על־טבעי המאפשר לו גישה אל העבר? בחזרה בלונדון, אדם מחליט ליצור קשר עם השכן, שמלבלב לכדי מערכת יחסים. הכתיבה זורמת ממנו בטבעיות ולצד המפגשים עם האהוב הפוטנציאלי ועם הייצוג של הוריו, צפים ועולים משקעי העבר. השאלה התיאורטית המרתקת בבסיס העלילה היא בעצם, אם הייתם יכולים לפגוש את ההורים שלכם כאשר הם בערך באותו גיל כמוכם, מה הייתם שואלים? אלו שיחות היו מתפתחות? זהו ג ...
# [{"article_id": "00000190-5479-ddd9-a1f1-d6fb66e80000", "article_name": "\"כולנו זרים\" לא הגיע לבתי הקולנוע בישראל – וזה פספוס ענק", "writer_name": ["אורון שמיר"], "review_type": "Movie", "genre": ["דרמה"], "distribution_platform": ["Disney+", "Apple TV+", "HOT", "Yes"], "short_summary": "סיפור אינטימי על אובדן ובדידות, עם משחק מרהיב של אנדרו סקוט.", "summary": "דרמה נוגה ומרגשת על תסריטאי בודד הפוגש את הוריו המתים ונכנס למערכת יחסים עם שכן מסתורי. סרט אינטימי על אובדן, בדידות וסליחה, עם הופעות משחק יוצאות דופן ובימוי רגיש.", "image_vertical": "https://img.haarets.co.il/bs/00000190-5479-ddd9-a1f1-d6fb64760000/c7/68/11cae054464ab00c35d5fc055924/57380633.JPG?precrop=918,1080,x301,y0", "author_image_square": "https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2024-06-26/ty-article-review/.premium/00000190-5479-ddd9-a1f1-d6fb66e80000"}, {"article_id": "0000017f-e160-d568-ad7f-f36bc7110000", "article_name": "\"תקופת מבחן\": לא בטוח שתראו בזמן הקרוב סרט דומה לזה", "writer_name": ["אורון שמיר"], "review_type": "Movie", "genre": ["דרמה", "קומדיה", "מוזיקלי"], "distribution_platform": ["Yes", "HOT"], "short_summary": "סרט ייחודי, מסוגנן, על חברות וסוגיות אמריקאיות אקטואליות.", "summary": "באוקלנד, שני חברי ילדות מתמודדים עם אתגרים אישיים וחברתיים קשים. קולין על תנאי, מיילס מתקשה עם הג'נטריפיקציה. סרט מסוגנן המשלב דרמה, קומדיה והיפ-הופ, בוחן סוגיות גזע וחברה באמריקה העכשווית.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-e160-d568-ad7f-f36bc65d0000/f2/a1/cf00a690aa9c552fa04cecce2ed2/4078017108.jpg?precrop=546,642,x63,y25", "author_image_square": "https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2020-08-02/ty-article-review/.premium/0000017f-e160-d568-ad7f-f36bc7110000"}]מצאתי שתי המלצות לסרטי דרמה איכותיים שזמינים בהוט: "'כולנו זרים'" ו"'תקופת מבחן'".
#
# אני מקווה שתיהנה מאחד מהם! יש לך עוד סרטים או סדרות שאתה מחפש המלצות עליהם?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513701", "input_tokens": 41988, "output_tokens": 75, "rag_speed": 0.6393389701843262, "llm_speed": 4.124501705169678, "total_time": 5.017528057098389}
# {"asctime": "2025-05-07 12:36:25,257", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Loaded history for user 1945513701 from Redis."}
# ====================
# Second Question: אשמח לתקציר נטול ספוילרים של 100 מילים בדיוק.
# בטח, הנה תקצירים נטולי ספוילרים לשני הסרטים שמצאתי:
#
# **כולנו זרים:**
# "כולנו זרים" היא דרמה נוגה ומרגשת על אדם, תסריטאי בודד בלונדון, שפוגש שכן מסתורי. במקביל, הוא חוזר לבית ילדותו ומוצא שם את הוריו המנוחים, כפי שהיו בשנת 1987, בגיל קרוב לשלו. המפגשים הבלתי צפויים מעוררים שאלות על עבר והווה, יחסים, זהות, זיכרון ואובדן, תוך התמקדות בחוויה של גבר גיי שגדל בשנות ה-80. הסרט משלב מציאות ופנטזיה במרחב לימינלי, בוחן בעומק את השפעת הילדות על חיינו הבוגרים. זו יצירה אינטימית, מרגשת, ולעיתים על-טבעית, העוסקת בבדידות וחיפוש אחר קשר.
#
# **תקופת מבחן:**
# "תקופת מבחן" מתרחש באוקלנד, קליפורניה, עיר הנאבקת עם שינויים ומתחים גזעיים. הסרט עוקב אחר קולין, גבר שחור הנמצא בסוף תקופת המבחן שלו וחייב להישאר נקי מצרות, וחברו הטוב מיילס, גבר לבן שגדל בשכונה. השניים עובדים יחד. כאשר קולין עד לאירוע הכולל ירי של שוטר, עולמו מתערער. עליו לבחור בין שמירה על שקט כדי להשלים את המבחן שלו, לבין המצפון שלו. הסרט משלב דרמה, הומור ושפה קולנועית ייחודית, כולל שימוש בראפ, כדי לחקור נושאים כמו זהות, חברות, והמציאות המורכבת של גזע באמריקה העכשווית.
#
# האם אחד מהתקצירים האלה עורר את סקרנותך במיוחד?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513701", "input_tokens": 42088, "output_tokens": 513, "rag_speed": 0, "llm_speed": 16.028826236724854, "total_time": 16.174816131591797}
# 2025-05-07 12:36:42.284 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-07 12:36:42.285 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# {"asctime": "2025-05-07 12:36:42,359", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "No history found for user 1945513702 in Redis."}
# ====================
# Article ID:
# Question: אני והחבר'ה רוצים לראות סרט אימה הערב. יש משהו ממש מפחיד שאתה מכיר?
# Warning: there are non-text parts in the response: ['function_call'],returning concatenated text result from text parts,check out the non text parts for full response from model.
# {"asctime": "2025-05-07 12:36:44,050", "name": "UNKNOWN_APP_NAME_logger", "levelname": "INFO", "message": "query=סרט אימה ממש מפחיד לראות הערב עם החבר'ה, streaming=[], genres=['אימה'], media_type=movie"}
# {"asctime": "2025-05-07 12:36:44,690", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Raw search_results for cost tracking: [{\"actors\": [\"ג'ורג'ינה קמפבל\", \"ביל סקארסגארד\", \"ג'סטין לונג\"], \"article_id\": \"00000184-2764-ddff-a586-ff67c3ed0000\", \"article_name\": \"\\\"ברברי\\\", סרט האימה המדובר של השנה, הגיע במפתיע לישראל\", \"article_type\": \"ReviewArticle\", \"author_image_square\": \"https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0\", \"brand\": \"HTZ\", \"create_by_AI\": false, \"director\": [\"זאק קרגר\"], \"distribution_platform\": [\"Disney+\"], \"genre\": [\"אימה\"], \"image_vertical\": \"https://img.haarets.co.il/bs/00000184-2764-ddff-a586-ff67c3400000/02/b2/acfa558549aebc298e4f5ebcdf37/49156779.JPG?precrop=1119,1317,x464,y0\", \"movie\": true, \"network\": [\"Disney+\"], \"paywall_status\": \"premium\", \"podcast\": false, \"producer\": [\"זאק קרגר\"], \"publish_time\": \"2022-10-30\", \"release_year\": 2022, \"review_type\": \"Movie\", \"section_primary\": \"תרבות\", \"section_secondary\": \"קולנוע\", \"section_tertiary\": \"ביקורת סרטים\", \"section_tertiary_id\": \"0000017d-d7fe-d276-a37f-f7fe02280000\", \"short_summary\": \"סרט האימה המדובר \\\"ברברי\\\" הגיע לישראל בדיסני+.\", \"stars\": 3.0, \"summary\": \"אישה מגיעה לדירה שהזמינה ומוצאת שם זר. סרט אימה מדובר שמשחק עם ציפיות הצופים ומציג התנהלות שונה של נשים וגברים במצבי סכנה, מפתיע ומבהיל.\", \"tag_names\": [\"קולנוע\"], \"text\": \"בלי שום הודעה מוקדמת, סרט האימה המדובר של השנה בארה\\\"ב צץ בשירות הסטרימינג של דיסני+ ושוב הצליח להפתיע את כולם. \\\"ברברי\\\" יצא לאקרנים בארה\\\"ב בתחילת ספטמבר, כלומר הרבה לפני שיאה של עונת הסרטים המפחידים בסוף אוקטובר — אבל נשאר מאז בבתי הקולנוע. שמו עבר מפה לאוזן וצבר לעצמו קהל מעריצים, מה שהוביל להכנסות שחצו את רף 40 מיליון דולר. רווח נאה בהתחשב בתקציב של כ–4.5 מיליון דולר. בדיוק בזמן לציון ליל כל הקדושים, הגיע הסרט גם אל המסך הביתי, ומכיוון שהזכויות שלו שייכות לאולפני פוקס לשעבר (כיום בבעלות תאגיד דיסני), האכסנייה הווירטואלית שלו היא שירות הסטרימינג של דיסני, שם אפילו לא הוכרז ביובש על בואו. הפתעה רודפת הפתעה בקמפיין השיווק, או היעדרו, כאשר גם הסרט עצמו הוא הכל חוץ מצפוי. למעשה, כדאי לדעת עליו כמה שפחות לפני הצפייה ורצוי לבדוק בעצמכם האם ההייפ מוצדק. כדי להימנע מספוילרים, אפשר להתייחס רק לנעשה במערכה הראשונה. התמטיקה של הסרט כולו ממילא מקופלת בחצי השעה הפותחת ואז מורחבת או מודגשת באירועים העוקבים, המסעפים את העלילה כמבוך מראות. נקודת המוצא מזכירה סרטי אימה אחרים על השכרת בתים זמניים, למשל \\\"הווילה\\\" או \\\"היית צריך לעזוב\\\" מהשנתיים האחרונות. טס (ג'ורג'ינה קמפבל, \\\"חשד\\\") מגיעה לדירה שהזמינה אונליין — ומגלה שם זר. זהו קית (ביל סקארסגארד, \\\"זה\\\") שהזמין את אותו הבית ברחוב ברברי 476 לאותו תאריך, אבל דרך שירות השכרה אחר. טס מבוהלת מן הסיטואציה, נטולת מקום מבטחים בשעת חשכה ובשכונה נחשלת בדטרויט. קית דווקא מזמין אותה להצטרף עד שיתבהר הבלבול. בשלב זה אפשר להיזכר כי לא רק סרטי אימה נפתחים כך, אלא גם קומדיות רומנטיות. למשל \\\"אהבה בווילה\\\" בנטפליקס. ההבדל בין נקודות המבט של הדמויות הוא לב לבו של הדיון הרעיוני המנוסח לאורך הסרט — הצגת האופנים השונים שבהם נשים וגברים רואים את העולם או מתנהלות בו. טס טוענת כי אם המצב היה הפוך היא אפילו לא היתה פותחת לו את הדלת, בעוד קית עיוור לאפשרות של סכנה. לדבריה זה משום שהיא אישה והוא גבר, מה שמציב אותו כאיום עבורה עד שיוכח אחרת. בניסיון להרגיעה, הוא שואל אותה אם הוא נראה כמו מפלצת, מה שמציף פנייה חוץ־קולנועית הממוענת אל הצופה הבקיא. זאת משום שהשחקן המגלם את קית מזוהה עם הדמות מסדרת סרטי האימה \\\"זה\\\" — פניווייז הליצן. האם לסמוך על הליהוק, המרמז שהוא שוב הנבל שאסור לנו לבטוח בו, או על הבחור חביב שלפנינו? המשחק עם ציפיות הקהל רק מתגבר בהמשך דרך דמות שלישית, בגילומו של ג'סטין לונג. גם כאן המטענים שמביא השחקן לתפקיד מובאים בחשבון, שכן לונג גילם לא פעם את הקורבן בסרטי אימה (\\\"ג'יפרס קריפרס\\\", \\\"טאסק\\\" ועוד). מערכת היחסים של הצופה והסרט מתהדקת בזכות קריצות כאלה, ומי שעומדים בגבורה בעשרות סרטי אימה בשנה ימצאו הרבה סיבות לפחד וליהנות מן המשחקים עם ה ...
# ...
# {"asctime": "2025-05-07 12:37:38,754", "name": "UNKNOWN_APP_NAME_logger", "levelname": "INFO", "message": "query=סרטי דוקו מעניינים, streaming=['Disney+', 'Apple TV+'], genres=['דוקומנטרי'], media_type=movie"}
# {"asctime": "2025-05-07 12:37:39,382", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Raw search_results for cost tracking: [{\"actors\": [\"סטיב מרטין\", \"טינה פיי\", \"ג'רי סיינפלד\", \"מרטין שורט\"], \"article_id\": \"0000018f-c9f2-da41-a9cf-d9fe60640000\", \"article_name\": \"\\\"סטיב!\\\": התיעוד הכפול על סטיב מרטין לוכד את קסמו\", \"article_type\": \"ReviewArticle\", \"author_image_square\": \"https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0\", \"brand\": \"HTZ\", \"create_by_AI\": false, \"director\": [\"מורגן נוויל\"], \"distribution_platform\": [\"Apple TV+\"], \"genre\": [\"דוקומנטרי\"], \"image_vertical\": \"https://img.haarets.co.il/bs/0000018f-c9f2-da41-a9cf-d9fe5adb0000/e3/fe/f306644542ebbd8c85d01c26daaf/57021830.JPG?precrop=1836,2160,x1782,y0\", \"minutes\": 191, \"movie\": true, \"network\": [\"Apple TV+\"], \"paywall_status\": \"premium\", \"podcast\": false, \"producer\": [\"מורגן נוויל\"], \"publish_time\": \"2024-05-30\", \"release_year\": 2024, \"review_type\": \"Movie\", \"section_primary\": \"תרבות\", \"section_secondary\": \"קולנוע\", \"section_tertiary\": \"ביקורת סרטים\", \"section_tertiary_id\": \"0000017d-d7fe-d276-a37f-f7fe02280000\", \"short_summary\": \"\\\"סטיב!\\\": תיעוד כפול לוכד קסמו של סטיב מרטין.\", \"stars\": 3.5, \"summary\": \"התיעוד הכפול על סטיב מרטין, בשני חלקים שונים, חושף את מסעו הארוך מעולם הסטנדאפ לקולנוע וטלוויזיה. הסרט לוכד את קסמו הנצחי, אישיותו המורכבת, והאבסורד המשמח המאפיין את יצירותיו.\", \"tag_names\": null, \"text\": \"סטיב מרטין הוא שם ידוע ופרצוף מוכר בכל העולם, אבל אולי צריך להיות אמריקאי כדי להכיר את מלוא הרפרטואר שלו. שנים לפני הקריירה הקולנועית, הקומיקאי הופיע על במות סטנדאפ ועשה זאת בדרכים שלא היו קיימות לפניו. אחר כך הגיעו \\\"החבובות\\\", הסרטים הקומיים, ולאחרונה הסדרה \\\"רק רוצחים בבניין\\\" (דיסני+) ולצדה ההופעות הבימתיות עם מרטין שורט, שותפו הוותיק להצחקה. מרטין ברוך כישרונות נוספים, ממעשי קוסמות דרך כתיבת ספרים וקומיקס ועד נגינה והלחנה מוזיקלית, כך שסרט תיעודי עליו הוא אך מתבקש. אבל בשל אורך הקריירה, שהחלה ב–1967 ונמשכת עד היום, כמו גם מגוון תחומי העיסוק, התוצאה היא שני סרטים באורך מלא. את הפרויקט המקיף תמצאו בשירות הסטרימינג של אפל תחת השם הספק מסבירני וספק מתחכם — Steve! (Martin) a documentary in 2 pieces. החלק הראשון, שהוא סרט בן שעה וחצי בפני עצמו, מתהדר בכותרת הביניים \\\"אז\\\". מרטין, לפני השיער הלבן וכולל אפילו תקופה קצרה של זקן, מספר על תחילת דרכו המקצועית בשנות ה–60. כיצד עבד בנעוריו כשולייה בחנות קסמים בדיסנילנד שבקליפורניה, ואיך לימודי הפילוסופיה באוניברסיטה הם שדחפו אותו לעלות על במה לנסות להצחיק. דרך כישורים שרכש בצעירותו ותוך הישענות על נטייה טבעית ללמוד ולהצטיין בתחומים מגוונים, מרטין יצר סגנון סטנדאפ ייחודי. הוא עטה על עצמו דמות נוירוטית, ולצד משפטי מחץ (\\\"סלחו לי!\\\") או נגינת בנג'ו וחיות עשויות בלונים, הוא זכור בזכות שילוב אביזרים משעשעים במופע. בעיקר כאלה שחבש על ראשו, מאוזני ארנב ועד חץ שכאילו מפלח אותו. עד 1980 זו היתה הקריירה שלו, בידור ילדותי למבוגרים, והוא מילא אולמות ענק בתקופה שסטנדאפ היתה אמנות הבדיחות הגסות במרתפים צפופים וטחובים. לתקופה מסוימת, הוא היה הקומיקאי הגדול באמריקה, עד שבחר לנסות את מזלו גם בקולנוע ובטלוויזיה.  חלק זה בפרויקט התיעודי מתאפיין בסגנון נוסטלגי — על המסך נראים אך ורק חומרי ארכיון, כולל יומנים שבהם חושף מרטין איך הרגיש אחרי הופעות, גרועות או מוצלחות. את הנרטיב מספק ברקע קולו של הבדרן, או מרואיינים השופכים אור על התקופה אבל אינם נראים. את הטון המתרפק מאזנים הנושאים החוזרים בדבריו או ביומניו של מרטין, בדגש על חרדה מכלה והשתוקקות לאהבת הקהל. הוא שב ומצפה להכרה וגאווה מצד הוריו, מה שלא קורה. לכן הוא מחפש אישור חיצוני בכל פעם שהוא עולה לבמה. אם תבחרו להאמין לו — ויש משהו כובש בכנות שלו כאדם וכקומיקאי — סטיב מרטין מצוי בחשש תמידי מן האפשרות שלא יאהבו אותו או את היצירה שלו, אבל מסרב ללכת על בטוח. זה מכמיר לב אבל לא חורג בהכרח מתדמית הליצן העצוב או הקומיקאי המלנכולי, שדבקה גם ברבים מעמיתיו. הסרט השני, שנקרא \\\"עכשיו\\\", הופך את הקערה על פיה, כאשר מוחלף הסגנון ומשתנה הטון. זהו סרט תיעודי פרונטל ...
# [{"article_id": "0000018f-c9f2-da41-a9cf-d9fe60640000", "article_name": "\"סטיב!\": התיעוד הכפול על סטיב מרטין לוכד את קסמו", "writer_name": ["אורון שמיר"], "review_type": "Movie", "genre": ["דוקומנטרי"], "distribution_platform": ["Apple TV+"], "short_summary": "\"סטיב!\": תיעוד כפול לוכד קסמו של סטיב מרטין.", "summary": "התיעוד הכפול על סטיב מרטין, בשני חלקים שונים, חושף את מסעו הארוך מעולם הסטנדאפ לקולנוע וטלוויזיה. הסרט לוכד את קסמו הנצחי, אישיותו המורכבת, והאבסורד המשמח המאפיין את יצירותיו.", "image_vertical": "https://img.haarets.co.il/bs/0000018f-c9f2-da41-a9cf-d9fe5adb0000/e3/fe/f306644542ebbd8c85d01c26daaf/57021830.JPG?precrop=1836,2160,x1782,y0", "author_image_square": "https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2024-05-30/ty-article-review/.premium/0000018f-c9f2-da41-a9cf-d9fe60640000"}, {"article_id": "0000017f-db17-d3a5-af7f-fbbfea840000", "article_name": "Boys State: אחד הסרטים התיעודיים היותר טובים שנראו השנה", "writer_name": ["אורון שמיר"], "review_type": "Movie", "genre": ["דוקומנטרי"], "distribution_platform": ["Apple TV+"], "short_summary": "תיעודי זוכה פרסים על בני נוער בונים דמוקרטיה בטקסס.", "summary": "זוכה סאנדנס \"מדינת הבנים\" עוקב אחר אלף בני נוער מטקסס הבונים דמוקרטיית דמה. הסרט חושף דרמות פוליטיות, רגעים אמוציונליים ותובנות עמוקות על הפוליטיקה האמריקאית והטבע האנושי דרך סיפוריהם.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-db17-d3a5-af7f-fbbfe9a30000/d3/7f/0c00eea961789f1e3cc911997b0f/2882235851.jpg?precrop=790,927,x168,y106", "author_image_square": "https://img.haarets.co.il/bs/00000184-dc9f-d3c9-a9a5-fd9f3f7f0001/8e/1e/784d834a44a792ba9fc12fbe9fdc/oronshamir2022.jpg?precrop=1661,1661,x90,y0", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2020-08-22/ty-article-review/.premium/0000017f-db17-d3a5-af7f-fbbfea840000"}]מצאתי עבורך כמה סרטים תיעודיים שיכולים לעניין אותך בדיסני פלוס או באפל טי וי פלוס.
#
# האם תרצה שאחפש לך סרטים או סדרות בז'אנרים נוספים?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513706", "input_tokens": 42764, "output_tokens": 60, "rag_speed": 0.6276931762695312, "llm_speed": 4.731230735778809, "total_time": 5.627208948135376}
# {"asctime": "2025-05-07 12:37:43,210", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Loaded history for user 1945513706 from Redis."}
# ====================
# Second Question: מהן הנקודות שהמבקרים הכי שיבחו בצילום (cinematography)? הבא שתי דוגמאות וציטוטים.
# בהחלט! מצאתי התייחסות מרתקת לנקודות שיא בצילום בסרט התיעודי **Boys State**, שמבקר "הארץ" שיבח.
#
# הנה שתי דוגמאות בולטות:
#
# 1.  **היכולת לתפוס רגעים מכריעים מקרוב ובזמן אמת:** המבקר התפעל מהאופן שבו הצילום הצליח להיות קרוב לאקשן ולתפוס קומפוזיציות משמעותיות בזמן שהדברים קורים, בלי לפספס רגעים חשובים, בין אם על הבמה או בקהל.
#     *   **ציטוט מהביקורת:** "לפעמים כל כך צמוד שאפשר לתהות כיצד הושגו הקומפוזיציות רבות המשמעות בזמן אמת ותוך כדי תנועה, או איך ייתכן שלא פוספס אף רגע על הבמות או בקהל."
#
# 2.  **עבודת הצלמים והבמאים בבחירת מושאי הצילום:** המבקר נותן קרדיט לצוות הצילום ולבמאים על שידעו בצורה אינטואיטיבית אחרי מי לעקוב במהלך האירועים הדינמיים, מה שתרם לבניית הנרטיב הוויזואלי.
#     *   **ציטוט מהביקורת:** "התשובה לכך היא שבעה צלמים חרוצים והרבה קרדיט לצמד הבמאים, אמנדה מקביין וג'סי מוס, שידעו בחושיהם אחרי מי לעקוב."
#
# הביקורת מדגישה שעבודת הצילום והבימוי ב-Boys State תרמו רבות להפיכת הסרט לחוויה קולנועית סוחפת ומרתקת.
#
# יש ז'אנרים או סגנונות צילום נוספים שמסקרנים אותך?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513706", "input_tokens": 42878, "output_tokens": 454, "rag_speed": 0, "llm_speed": 8.103632926940918, "total_time": 8.256848812103271}
# 2025-05-07 12:37:52.340 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-07 12:37:52.340 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# {"asctime": "2025-05-07 12:37:52,415", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "No history found for user 1945513707 in Redis."}
# ====================
# Article ID:
# Question: סתם תן המלצה לסרט טוב שראית לאחרונה, לא משנה לי הז'אנר או הפלטפורמה.
# Warning: there are non-text parts in the response: ['function_call'],returning concatenated text result from text parts,check out the non text parts for full response from model.
# {"asctime": "2025-05-07 12:37:53,563", "name": "UNKNOWN_APP_NAME_logger", "levelname": "INFO", "message": "query=המלצה לסרט טוב, streaming=[], genres=[], media_type=movie"}
# {"asctime": "2025-05-07 12:37:54,168", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Raw search_results for cost tracking: [{\"actors\": [\"איזבל אופר\", \"ז'אן־לואי טרינטיניאן\", \"מתייה קסוביץ\", \"פנטין הרדואן\", \"פרנץ רוגובסקי\", \"טובי ג'ונס\", \"לורה ורלינדן\", \"חסם גאנסי\", \"נביאה אקארי\"], \"article_id\": \"0000017f-f59b-ddde-abff-fdffb9960000\", \"article_name\": \"אז מה אם \\\"סוף טוב\\\" של מיכאל האנקה הוא לא יצירת מופת\", \"article_type\": \"ReviewArticle\", \"author_image_square\": \"https://img.haarets.co.il/bs/0000017f-da2a-d249-ab7f-fbea2dce0000/78/a2/42ecfd18548356c5cf8cb359d90c/2744759269.jpg?precrop=1467,1468,x616,y0\", \"brand\": \"HTZ\", \"create_by_AI\": false, \"director\": [\"מיכאל האנקה\"], \"distribution_platform\": [\"בתי קולנוע\"], \"genre\": [\"דרמה\"], \"image_vertical\": \"https://img.haarets.co.il/bs/0000017f-f59b-ddde-abff-fdffb90b0000/10/54/31cc007f4bf21b35b4d075b607ce/3593270975.jpg\", \"movie\": true, \"network\": null, \"paywall_status\": \"premium\", \"podcast\": false, \"producer\": [\"מיכאל האנקה\"], \"publish_time\": \"2017-11-21\", \"release_year\": 2017, \"review_type\": \"Movie\", \"section_primary\": \"תרבות\", \"section_secondary\": \"קולנוע\", \"section_tertiary\": \"ביקורת סרטים\", \"section_tertiary_id\": \"0000017d-d7fe-d276-a37f-f7fe02280000\", \"short_summary\": \"חוויה אינטליגנטית, דיוקן קר ואירוני, מבט מרוחק ומטריד.\", \"stars\": 4.0, \"summary\": \"סרטו של מיכאל האנקה מציג דיוקן קר ואירוני של משפחה בורגנית באמצעות טכנולוגיה. למרות המרחק הרגשי, הוא מספק חוויה אינטליגנטית ומטרידה על מהות האנושות.\", \"tag_names\": [\"קולנוע\"], \"text\": \"\\\"סוף טוב\\\", סרטו החדש של מיכאל האנקה, לא יצטרף ל\\\"מחבואים\\\" מ-2005, \\\"סרט לבן\\\" מ-2009 ו\\\"אהבה\\\" מ-2012, רשימת יצירות המופת של הבמאי האוסטרי, העובד בעיקר בצרפת. אך אין זה אומר שאין בו מה להעריך וממה ליהנות. רבים מסממניו התמטיים והצורניים של האנקה מאפיינים גם את \\\"סוף טוב\\\", ונדמה כי הסרט משוטט לאורך יצירתו של הבמאי, החל ב\\\"הווידיאו של בני\\\", שהחדיר את שמו לתודעתנו ב-1992: כפי שגיבורו הצעיר של הסרט המטריד והמטלטל ההוא היה שבוי בנפלאותיו של התיעוד בווידיאו עד שניתק מהמציאות וחצה את הגבול בין המותר לאסור, כך הטכנולוגיה העכשווית משמשת כלי בידיו של האנקה כדי לתעד את המגוחך, המנוכר והאכזרי במציאות של סרטו החדש. בפתח הסרט מתעדת ילדה, שאיננו רואים אך היא כנראה איב בת ה-12 (פנטין הרדואן), בטלפון שלה את סדר הפעולות שאמה עושה קודם שהיא שוכבת לישון. כל פעולה שכזאת הילדה מציינת בשמה. מיד לאחר מכן, וגם זאת בצילום בטלפון, הילדה, שעדיין איננו רואים אותה, בודקת את השפעתם של נוגדי הדיכאון שאמה לוקחת על האוגר שלה, והתוצאה היא כמובן מותו של האוגר. משתי סצינות אלה, המוצגות לפנינו כפי שנקלטו במצלמת הטלפון של הילדה האלמונית עדיין, עובר הסרט לצילום מרחוק של אתר בנייה, המוצג בשוט ארוך שבסופו תאונה הקוטעת זמנית את הפעילות באתר. השילוב הזה, בין הקרוב לרחוק, משמש לעתים קרובות סממן מרכזי ביצירתו של האנקה: הקרוב אינו מגלה לנו את המתרחש באמת במציאות של הסרט, והרחוק – שלעתים הוא כה רחוק שאיננו בטוחים מה אנו בעצם רואים – תורם למציאות זו מסתורין ותחושה של ניכור תמידי. ב\\\"סוף טוב\\\" יש סצינות רבות המצולמות מקרוב, ולמרות זאת הוא נדמה לסרט שצולם כולו מרחוק; זה האפקט הדרמטי והרגשי שהוא יוצר. כמו רבים מסרטיו הקודמים של האנקה, הסרט משרטט דיוקן קר ואירוני של בורגנות. הפעם דיוקן זה ממוקד במשפחת לוראן, בעלת חברת הבנייה שאתר התאונה היה באחריותה, המתגוררת באחוזה משפחתית בקאלה, עיר שרבים מהמהגרים לצרפת הגיעו אליה. ז'ורז' (ז'אן־לואי טרינטיניאן), אב המשפחה בן ה-85, ישוב בכיסא גלגלים, מודע לסניליות שלו, ורק שואף לסיים את חייו. הוא העביר את ניהול החברה לאן (איזבל אופר), בתו המעשית והקשוחה, וזו מתכוונת להעבירו בעתיד לבנה פייר (פרנץ רוגובסקי), אלא שהסיכויים לכך קטנים בגלל אופיו המעורער של הבן וסלידתו מהמשפחה. לאן יש אח בשם תומס (מתייה קסוביץ), רופא, נשוי בשנית, לאנאיס (לורה ורלינדן), ואב לתינוק. עובדות אלה אינן מונעות ממנו לנהל רומן, ואת המסרים הנלהבים רומנטית ומינית, שהוא מחליף עם אהובתו בלילה באינטרנט, האנקה מציג לפנינו כתובים על המסך בסצינה ארוכה, מה שמבליט את תחושת הגיחוך והניכור שבהם. אחרי שאשתו הראשונה של תומס מאושפזת בשל מנת יתר ש ...
# [{"article_id": "0000017f-f59b-ddde-abff-fdffb9960000", "article_name": "אז מה אם \"סוף טוב\" של מיכאל האנקה הוא לא יצירת מופת", "writer_name": ["אורי קליין"], "review_type": "Movie", "genre": ["דרמה"], "distribution_platform": ["בתי קולנוע"], "short_summary": "חוויה אינטליגנטית, דיוקן קר ואירוני, מבט מרוחק ומטריד.", "summary": "סרטו של מיכאל האנקה מציג דיוקן קר ואירוני של משפחה בורגנית באמצעות טכנולוגיה. למרות המרחק הרגשי, הוא מספק חוויה אינטליגנטית ומטרידה על מהות האנושות.", "image_vertical": "https://img.haarets.co.il/bs/0000017f-f59b-ddde-abff-fdffb90b0000/10/54/31cc007f4bf21b35b4d075b607ce/3593270975.jpg", "author_image_square": "https://img.haarets.co.il/bs/0000017f-da2a-d249-ab7f-fbea2dce0000/78/a2/42ecfd18548356c5cf8cb359d90c/2744759269.jpg?precrop=1467,1468,x616,y0", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2017-11-21/ty-article-review/.premium/0000017f-f59b-ddde-abff-fdffb9960000"}, {"article_id": "00000187-0f86-dce9-afc7-5fcef1ac0000", "article_name": "\"הנפש הטובה\" חושף עולם מעוות ונצלני, בלי נפש טובה אחת", "writer_name": ["פבלו אוטין"], "review_type": "Movie", "genre": ["דרמה"], "distribution_platform": ["בתי קולנוע"], "short_summary": "עולם קולנוע מעוות ונצלני חושף היעדר נפשות טובות.", "summary": "דרמה אפלה ומסוגננת בסגנון נואר, חושפת עולם קולנוע ציני ונצלני. מורן רוזנבלט מגלמת מפיקה הנאבקת לשרוד בהפקה כאוטית. סרט אכזרי וכואב על חיפוש אחר נחמה בעולם ללא נפש טובה.", "image_vertical": "https://img.haarets.co.il/bs/00000187-0f86-dce9-afc7-5fcef0d80000/b6/b7/3cec4deb45bc83a65dd8b4535fda/51191220.JPG?precrop=584,687,x38,y0", "author_image_square": "https://img.haarets.co.il/bs/00000188-aaa7-db59-a19a-feefc57d0001/ad/b1/e4ed9f91467c886286018cb59872/48874.png?precrop=1366,1366,x239,y0", "url": "https://www.haaretz.co.il/gallery/cinema/movie-reviews/2023-03-23/ty-article-review/.premium/00000187-0f86-dce9-afc7-5fcef1ac0000"}]שמחה שהצלחתי למצוא לך כמה המלצות לסרטים טובים!
#
# האם תרצה שאמליץ לך על סרטים נוספים בז'אנרים אחרים, או אולי סדרות?{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513707", "input_tokens": 43638, "output_tokens": 53, "rag_speed": 0.605025053024292, "llm_speed": 3.053260087966919, "total_time": 3.9123482704162598}
# {"asctime": "2025-05-07 12:37:56,995", "name": "UNKNOWN_APP_NAME_logger", "levelname": "DEBUG", "message": "Loaded history for user 1945513707 from Redis."}
# ====================
# Second Question: מבחינת Diversity & Inclusion—האם הסרט קיבל ביקורת חיובית או שלילית? הבא נתונים.
# על מנת לענות על שאלתך בנוגע לביקורות על הסרטים שהוזכרו מזווית של Diversity & Inclusion, אבדוק את המאמרים שברשותי. אריץ חיפוש ספציפי במאגר הנתונים על הסרטים ועל המונחים שציינת.
#
# אנא המתן רגע בזמן שאני מאחזר את המידע הרלוונטי מהביקורות.{"version": "1.0", "model": "gemini-2.5-flash-preview-04-17", "user_id": "1945513707", "input_tokens": 43720, "output_tokens": 104, "rag_speed": 0, "llm_speed": 7.951589822769165, "total_time": 8.095568895339966}

# %%
import pandas as pd
pd.DataFrame(result).to_excel('first_question_article.xlsx', index=False)
